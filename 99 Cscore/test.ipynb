# %%
import pandas as pd
from utils import all_history, transform_files
import glob
import numpy as np
import pandas as pd
import glob
# import win32com.client as win32
import jaydebeapi
from const import QUERY, CONNECT
import re

# %%
conn = jaydebeapi.connect(
        CONNECT.DB,
        CONNECT.PORT,
        CONNECT.USER,
        CONNECT.CNN,
        )
cur = conn.cursor()  

query = pd.read_sql(f'''
      SELECT * FROM SIREETRON.bucket_score  
    ''', conn) 
conn.close()


file_current = glob.glob("./input/acc_current/*.csv") 
file_current = file_current[0].split('\\')[1]
print(f'file_oa_current :, {file_current} ?? ')
# Out:
# file_oa_current :, Acc_20250201_0830.csv ??
# C:\Users\Sireetron\AppData\Local\Temp\ipykernel_26440\2551003257.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   query = pd.read_sql(f'''

# %%
from utils import read_file,clean_column_names

# %%
data_digit1 = read_file('./input/acc_current/',file_current)
data_digit1 = clean_column_names(data_digit1)
# data_digit1 = pd.read_csv(f'./input/acc_current/{file_current}')
data_digit1['contract_no'] = data_digit1['contract_no'].astype(str)
data_digit1 = data_digit1[['contract_no']]
# Out:
# Successfully read Acc_20250201_0830.csv using utf-8 encoding.

# %%
data_digit1
# Out:
#               contract_no
# 0        9010221122000949
# 1        9010221122000931
# 2        9010221122000922
# 3        9010221122000914
# 4        9010221122000906
# ...                   ...
# 1366988  1000158090014831
# 1366989  1000158090014814
# 1366990  1000158090008580
# 1366991  1000158090005394
# 1366992  1000158080014811
#
# [1366993 rows x 1 columns]

# %%
files_history = glob.glob("./input/acc_history_monthly/*.csv") 
files_history
# Out:
# ['./input/acc_history_monthly\\Acc_20240901_0830.csv',
#  './input/acc_history_monthly\\Acc_20241001_0830.csv',
#  './input/acc_history_monthly\\Acc_20241101_0830.csv',
#  './input/acc_history_monthly\\Acc_20241201_0830.csv',
#  './input/acc_history_monthly\\Acc_20250101_0830.csv',
#  './input/acc_history_monthly\\Acc_20250201_0830.csv']

# %%
processed_files = []  # Store modified file names
for i in files_history:
    # print()
    file = i.split('\\')[-1] 
    # print(file)
    processed_files.append(file)  
his = transform_files(processed_files)

# %%
data_digit1 = pd.read_csv(f'./input/acc_current/{file_current}')
data_digit1['Loan No'] = data_digit1['Loan No'].astype(str)
data_digit1 = data_digit1[['Loan No']]
files_history = glob.glob("./input/acc_history_monthly/*.csv") 
# print(f'file_history :, {files_history} ?? ')
processed_files = []  # Store modified file names

for i in files_history:
    # print()
    file = i.split('\\')[-1] 
    # print(file)
    processed_files.append(file)  
his = transform_files(processed_files)

# %%
his
# Out:
# [['Acc_20250201_0830.csv', 'Acc_20250201_0830'],
#  ['Acc_20250101_0830.csv', 'Acc_20250101_0830'],
#  ['Acc_20241201_0830.csv', 'Acc_20241201_0830'],
#  ['Acc_20241101_0830.csv', 'Acc_20241101_0830'],
#  ['Acc_20241001_0830.csv', 'Acc_20241001_0830'],
#  ['Acc_20240901_0830.csv', 'Acc_20240901_0830']]

# %%
for i in his[0:]:
    # print(f"Processing date: {i[0]}")
    # print((i[0], i[1]))
    data = all_history(query,i[0], i[1])
    data = clean_column_names(data)
    data_digit1 = data_digit1.merge(data, on='contract_no', how='left')
# Out:
# c:\Users\Sireetron\automated\kbj_automation\99 Cscore\utils.py:19: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_mnt = pd.read_csv(f'./input/acc_history_monthly/{date}')
# c:\Users\Sireetron\automated\kbj_automation\99 Cscore\utils.py:19: DtypeWarning: Columns (1,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_mnt = pd.read_csv(f'./input/acc_history_monthly/{date}')
# c:\Users\Sireetron\automated\kbj_automation\99 Cscore\utils.py:19: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_mnt = pd.read_csv(f'./input/acc_history_monthly/{date}')

# %%
data_performance = pd.read_csv('./input/performance_peronal_info/performance.csv')
data_performance
# Out:
# C:\Users\Sireetron\AppData\Local\Temp\ipykernel_26440\295288314.py:1: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_performance = pd.read_csv('./input/performance_peronal_info/performance.csv')
#                       AS_OF_DATE       CONTRACT_NO    NATIONAL_ID  \
# 0        2025-03-19 00:00:00.000  5000161051018231  1110300202706
# 1        2025-03-19 00:00:00.000  1000161051042121  1110300202706
# 2        2025-03-19 00:00:00.000  5002461061050530  1110300203281
# 3        2025-03-19 00:00:00.000  5000361021006968  1110300205578
# 4        2025-03-19 00:00:00.000  5000461041075891  1110300208135
# ...                          ...               ...            ...
# 5386968  2025-03-19 00:00:00.000  7250170104680761  3800400714270
# 5386969  2025-03-19 00:00:00.000  7241270104483495  1301400032895
# 5386970  2025-03-19 00:00:00.000  7250170104615532  5361200029818
# 5386971  2025-03-19 00:00:00.000  7250170104600813  3720200607489
# 5386972  2025-03-19 00:00:00.000  7250170104600865  3730100965448
#
#          GROSS_INCOME  OCCUPATION_TYPE              OCCUPATION_NAME  \
# 0              9750.0              9.0        PRODUCTION LINE LABOR
# 1              9750.0              9.0        PRODUCTION LINE LABOR
# 2             10140.0              5.0                  OFFICE WORK
# 3              9300.0             10.0                GENERAL LABOR
# 4             13737.0              9.0        PRODUCTION LINE LABOR
# ...               ...              ...                          ...
# 5386968       12500.0              4.0               SPECIALIZATION
# 5386969       17500.0              5.0                  OFFICE WORK
# 5386970       50500.0              2.0  UNREGISTERED BUSINESS OWNER
# 5386971       17500.0              9.0        PRODUCTION LINE LABOR
# 5386972       50500.0              1.0    REGISTERED BUSINESS OWNER
#
#                    CONTRACT_DATE  CONTRACT_PERIOD   AGE  PRINCIPAL_BAL  MOB  \
# 0        2018-05-07 00:00:00.000             82.0  27.0           0.00    7
# 1        2018-05-14 00:00:00.000             82.0  27.0         801.00    7
# 2        2018-06-13 00:00:00.000             81.0  27.0           0.00    7
# 3        2018-02-02 00:00:00.000             85.0  27.0       13890.67    7
# 4        2018-04-26 00:00:00.000             82.0  27.0           0.00    7
# ...                          ...              ...   ...            ...  ...
# 5386968  2025-01-31 00:00:00.000              1.0  41.0           0.00    6
# 5386969  2024-12-28 00:00:00.000              2.0  39.0           0.00    6
# 5386970  2025-01-19 00:00:00.000              2.0  59.0       24211.25    6
# 5386971  2025-01-16 00:00:00.000              2.0  46.0           0.00    6
# 5386972  2025-01-16 00:00:00.000              2.0  44.0           0.00    6
#
#          DIGIT2INCOME  DIGIT2AGE  DIGIT2JOB  TOTAL_DIGIT2
# 0                   3          3          3             3
# 1                   3          3          3             3
# 2                   3          3          1             3
# 3                   3          3          2             3
# 4                   3          3          3             3
# ...               ...        ...        ...           ...
# 5386968             3          2          1             2
# 5386969             3          3          1             3
# 5386970             2          1          3             2
# 5386971             3          2          3             3
# 5386972             2          2          3             3
#
# [5386973 rows x 15 columns]

# %%
def clean_column_names(df):
    df.columns = df.columns.str.lower()  # Convert to lowercase
    df.columns = df.columns.str.replace(r'\.', '', regex=True)
    df.columns = df.columns.str.replace(r' ', '_', regex=True)  # Replace non-alphanumeric characters with underscores
    df.columns = df.columns.str.replace('customer_id_no|customer_no|customer_id|national_id', 'customer_no', regex=True)  # Replace variations with 'customer_no'
    df.columns = df.columns.str.replace(r'loan_no', 'contract_no', regex=True)
    df.columns = df.columns.str.replace(r'mobile.*', 'mobile_no', regex=True)
    df.columns = df.columns.str.replace(r'customer_name/surname\(thai\)', 'customer_name', regex=True)  # Replace 'customer_name/surname(thai)' with 'customer_name'
    return df

# %%
data_performance = clean_column_names(data_performance)
# data_performance
# Out:
#                       as_of_date       contract_no    customer_no  \
# 0        2025-03-19 00:00:00.000  5000161051018231  1110300202706
# 1        2025-03-19 00:00:00.000  1000161051042121  1110300202706
# 2        2025-03-19 00:00:00.000  5002461061050530  1110300203281
# 3        2025-03-19 00:00:00.000  5000361021006968  1110300205578
# 4        2025-03-19 00:00:00.000  5000461041075891  1110300208135
# ...                          ...               ...            ...
# 5386968  2025-03-19 00:00:00.000  7250170104680761  3800400714270
# 5386969  2025-03-19 00:00:00.000  7241270104483495  1301400032895
# 5386970  2025-03-19 00:00:00.000  7250170104615532  5361200029818
# 5386971  2025-03-19 00:00:00.000  7250170104600813  3720200607489
# 5386972  2025-03-19 00:00:00.000  7250170104600865  3730100965448
#
#          gross_income  occupation_type              occupation_name  \
# 0              9750.0              9.0        PRODUCTION LINE LABOR
# 1              9750.0              9.0        PRODUCTION LINE LABOR
# 2             10140.0              5.0                  OFFICE WORK
# 3              9300.0             10.0                GENERAL LABOR
# 4             13737.0              9.0        PRODUCTION LINE LABOR
# ...               ...              ...                          ...
# 5386968       12500.0              4.0               SPECIALIZATION
# 5386969       17500.0              5.0                  OFFICE WORK
# 5386970       50500.0              2.0  UNREGISTERED BUSINESS OWNER
# 5386971       17500.0              9.0        PRODUCTION LINE LABOR
# 5386972       50500.0              1.0    REGISTERED BUSINESS OWNER
#
#                    contract_date  contract_period   age  principal_bal  mob  \
# 0        2018-05-07 00:00:00.000             82.0  27.0           0.00    7
# 1        2018-05-14 00:00:00.000             82.0  27.0         801.00    7
# 2        2018-06-13 00:00:00.000             81.0  27.0           0.00    7
# 3        2018-02-02 00:00:00.000             85.0  27.0       13890.67    7
# 4        2018-04-26 00:00:00.000             82.0  27.0           0.00    7
# ...                          ...              ...   ...            ...  ...
# 5386968  2025-01-31 00:00:00.000              1.0  41.0           0.00    6
# 5386969  2024-12-28 00:00:00.000              2.0  39.0           0.00    6
# 5386970  2025-01-19 00:00:00.000              2.0  59.0       24211.25    6
# 5386971  2025-01-16 00:00:00.000              2.0  46.0           0.00    6
# 5386972  2025-01-16 00:00:00.000              2.0  44.0           0.00    6
#
#          digit2income  digit2age  digit2job  total_digit2
# 0                   3          3          3             3
# 1                   3          3          3             3
# 2                   3          3          1             3
# 3                   3          3          2             3
# 4                   3          3          3             3
# ...               ...        ...        ...           ...
# 5386968             3          2          1             2
# 5386969             3          3          1             3
# 5386970             2          1          3             2
# 5386971             3          2          3             3
# 5386972             2          2          3             3
#
# [5386973 rows x 15 columns]

# %%
data_digit1['contract_no'] = data_digit1['contract_no'].astype(str)
data_performance['contract_no']= data_performance['contract_no'].astype(str)
data_performance
# Out:
#                       as_of_date       contract_no    customer_no  \
# 0        2025-03-19 00:00:00.000  5000161051018231  1110300202706
# 1        2025-03-19 00:00:00.000  1000161051042121  1110300202706
# 2        2025-03-19 00:00:00.000  5002461061050530  1110300203281
# 3        2025-03-19 00:00:00.000  5000361021006968  1110300205578
# 4        2025-03-19 00:00:00.000  5000461041075891  1110300208135
# ...                          ...               ...            ...
# 5386968  2025-03-19 00:00:00.000  7250170104680761  3800400714270
# 5386969  2025-03-19 00:00:00.000  7241270104483495  1301400032895
# 5386970  2025-03-19 00:00:00.000  7250170104615532  5361200029818
# 5386971  2025-03-19 00:00:00.000  7250170104600813  3720200607489
# 5386972  2025-03-19 00:00:00.000  7250170104600865  3730100965448
#
#          gross_income  occupation_type              occupation_name  \
# 0              9750.0              9.0        PRODUCTION LINE LABOR
# 1              9750.0              9.0        PRODUCTION LINE LABOR
# 2             10140.0              5.0                  OFFICE WORK
# 3              9300.0             10.0                GENERAL LABOR
# 4             13737.0              9.0        PRODUCTION LINE LABOR
# ...               ...              ...                          ...
# 5386968       12500.0              4.0               SPECIALIZATION
# 5386969       17500.0              5.0                  OFFICE WORK
# 5386970       50500.0              2.0  UNREGISTERED BUSINESS OWNER
# 5386971       17500.0              9.0        PRODUCTION LINE LABOR
# 5386972       50500.0              1.0    REGISTERED BUSINESS OWNER
#
#                    contract_date  contract_period   age  principal_bal  mob  \
# 0        2018-05-07 00:00:00.000             82.0  27.0           0.00    7
# 1        2018-05-14 00:00:00.000             82.0  27.0         801.00    7
# 2        2018-06-13 00:00:00.000             81.0  27.0           0.00    7
# 3        2018-02-02 00:00:00.000             85.0  27.0       13890.67    7
# 4        2018-04-26 00:00:00.000             82.0  27.0           0.00    7
# ...                          ...              ...   ...            ...  ...
# 5386968  2025-01-31 00:00:00.000              1.0  41.0           0.00    6
# 5386969  2024-12-28 00:00:00.000              2.0  39.0           0.00    6
# 5386970  2025-01-19 00:00:00.000              2.0  59.0       24211.25    6
# 5386971  2025-01-16 00:00:00.000              2.0  46.0           0.00    6
# 5386972  2025-01-16 00:00:00.000              2.0  44.0           0.00    6
#
#          digit2income  digit2age  digit2job  total_digit2
# 0                   3          3          3             3
# 1                   3          3          3             3
# 2                   3          3          1             3
# 3                   3          3          2             3
# 4                   3          3          3             3
# ...               ...        ...        ...           ...
# 5386968             3          2          1             2
# 5386969             3          3          1             3
# 5386970             2          1          3             2
# 5386971             3          2          3             3
# 5386972             2          2          3             3
#
# [5386973 rows x 15 columns]

# %%
data_digit1
# Out:
#               contract_no bucket_scoreacc_20250201_0830mnt  \
# 0        9010221122000949                                5
# 1        9010221122000931                                0
# 2        9010221122000922                               13
# 3        9010221122000914                               13
# 4        9010221122000906                               13
# ...                   ...                              ...
# 1366988  1000158090014831                                0
# 1366989  1000158090014814                                0
# 1366990  1000158090008580                                0
# 1366991  1000158090005394                                0
# 1366992  1000158080014811                                0
#
#         bucket_scoreacc_20250101_0830mnt bucket_scoreacc_20241201_0830mnt  \
# 0                                      5                                5
# 1                                      0                                0
# 2                                     13                               13
# 3                                     13                               13
# 4                                     13                               13
# ...                                  ...                              ...
# 1366988                                0                                0
# 1366989                                0                                0
# 1366990                                0                                0
# 1366991                                0                                0
# 1366992                                0                                0
#
#         bucket_scoreacc_20241101_0830mnt bucket_scoreacc_20241001_0830mnt  \
# 0                                      5                                5
# 1                                      0                                0
# 2                                     13                               13
# 3                                     13                               13
# 4                                     13                               13
# ...                                  ...                              ...
# 1366988                                0                                0
# 1366989                                0                                0
# 1366990                                0                                0
# 1366991                                0                                0
# 1366992                                0                                0
#
#         bucket_scoreacc_20240901_0830mnt  avg_digit1
# 0                                      5         0.0
# 1                                      0         0.0
# 2                                     13         0.0
# 3                                     13         0.0
# 4                                     13         0.0
# ...                                  ...         ...
# 1366988                              NaN         0.0
# 1366989                              NaN         0.0
# 1366990                              NaN         0.0
# 1366991                              NaN         0.0
# 1366992                              NaN         0.0
#
# [1366993 rows x 8 columns]

# %%
data_digit1['avg_digit1'] = data_digit1.loc[:, data_digit1.columns.str.startswith('bucket_score')].apply(pd.to_numeric, errors='coerce').sum(axis=1).fillna(0).astype(int)/6

# %%
data_digit1
# Out:
#               contract_no bucket_scoreacc_20250201_0830mnt  \
# 0        9010221122000949                                5
# 1        9010221122000931                                0
# 2        9010221122000922                               13
# 3        9010221122000914                               13
# 4        9010221122000906                               13
# ...                   ...                              ...
# 1366988  1000158090014831                                0
# 1366989  1000158090014814                                0
# 1366990  1000158090008580                                0
# 1366991  1000158090005394                                0
# 1366992  1000158080014811                                0
#
#         bucket_scoreacc_20250101_0830mnt bucket_scoreacc_20241201_0830mnt  \
# 0                                      5                                5
# 1                                      0                                0
# 2                                     13                               13
# 3                                     13                               13
# 4                                     13                               13
# ...                                  ...                              ...
# 1366988                                0                                0
# 1366989                                0                                0
# 1366990                                0                                0
# 1366991                                0                                0
# 1366992                                0                                0
#
#         bucket_scoreacc_20241101_0830mnt bucket_scoreacc_20241001_0830mnt  \
# 0                                      5                                5
# 1                                      0                                0
# 2                                     13                               13
# 3                                     13                               13
# 4                                     13                               13
# ...                                  ...                              ...
# 1366988                                0                                0
# 1366989                                0                                0
# 1366990                                0                                0
# 1366991                                0                                0
# 1366992                                0                                0
#
#         bucket_scoreacc_20240901_0830mnt  avg_digit1
# 0                                      5         5.0
# 1                                      0         0.0
# 2                                     13        13.0
# 3                                     13        13.0
# 4                                     13        13.0
# ...                                  ...         ...
# 1366988                              NaN         0.0
# 1366989                              NaN         0.0
# 1366990                              NaN         0.0
# 1366991                              NaN         0.0
# 1366992                              NaN         0.0
#
# [1366993 rows x 8 columns]

# %%
data_digit1['avg_digit1'] = data_digit1.loc[:, data_digit1.columns.str.startswith('BUCKET_SCORE')].apply(pd.to_numeric, errors='coerce').sum(axis=1).fillna(0).astype(int)/6

# %%
data_all_digit = data_performance.merge(data_digit1, left_on='contract_no', right_on='contract_no', how='left')
# data_all_digit['AVG_DIGIT1'] = data_all_digit.loc[:, data_all_digit.columns.str.startswith('SCORE_INDEX')].apply(pd.to_numeric, errors='coerce').mean(axis=1).fillna(0).astype(int)
data_all_digit['mob'] = pd.to_numeric(data_all_digit['mob'], errors='coerce').fillna(0).astype(int)
data_all_digit
# Out:
#                       as_of_date       contract_no    customer_no  \
# 0        2025-03-19 00:00:00.000  5000161051018231  1110300202706
# 1        2025-03-19 00:00:00.000  1000161051042121  1110300202706
# 2        2025-03-19 00:00:00.000  5002461061050530  1110300203281
# 3        2025-03-19 00:00:00.000  5000361021006968  1110300205578
# 4        2025-03-19 00:00:00.000  5000461041075891  1110300208135
# ...                          ...               ...            ...
# 5386968  2025-03-19 00:00:00.000  7250170104680761  3800400714270
# 5386969  2025-03-19 00:00:00.000  7241270104483495  1301400032895
# 5386970  2025-03-19 00:00:00.000  7250170104615532  5361200029818
# 5386971  2025-03-19 00:00:00.000  7250170104600813  3720200607489
# 5386972  2025-03-19 00:00:00.000  7250170104600865  3730100965448
#
#          gross_income  occupation_type              occupation_name  \
# 0              9750.0              9.0        PRODUCTION LINE LABOR
# 1              9750.0              9.0        PRODUCTION LINE LABOR
# 2             10140.0              5.0                  OFFICE WORK
# 3              9300.0             10.0                GENERAL LABOR
# 4             13737.0              9.0        PRODUCTION LINE LABOR
# ...               ...              ...                          ...
# 5386968       12500.0              4.0               SPECIALIZATION
# 5386969       17500.0              5.0                  OFFICE WORK
# 5386970       50500.0              2.0  UNREGISTERED BUSINESS OWNER
# 5386971       17500.0              9.0        PRODUCTION LINE LABOR
# 5386972       50500.0              1.0    REGISTERED BUSINESS OWNER
#
#                    contract_date  contract_period   age  principal_bal  ...  \
# 0        2018-05-07 00:00:00.000             82.0  27.0           0.00  ...
# 1        2018-05-14 00:00:00.000             82.0  27.0         801.00  ...
# 2        2018-06-13 00:00:00.000             81.0  27.0           0.00  ...
# 3        2018-02-02 00:00:00.000             85.0  27.0       13890.67  ...
# 4        2018-04-26 00:00:00.000             82.0  27.0           0.00  ...
# ...                          ...              ...   ...            ...  ...
# 5386968  2025-01-31 00:00:00.000              1.0  41.0           0.00  ...
# 5386969  2024-12-28 00:00:00.000              2.0  39.0           0.00  ...
# 5386970  2025-01-19 00:00:00.000              2.0  59.0       24211.25  ...
# 5386971  2025-01-16 00:00:00.000              2.0  46.0           0.00  ...
# 5386972  2025-01-16 00:00:00.000              2.0  44.0           0.00  ...
#
#          digit2age  digit2job  total_digit2  bucket_scoreacc_20250201_0830mnt  \
# 0                3          3             3                               NaN
# 1                3          3             3                               NaN
# 2                3          1             3                               NaN
# 3                3          2             3                                13
# 4                3          3             3                               NaN
# ...            ...        ...           ...                               ...
# 5386968          2          1             2                               NaN
# 5386969          3          1             3                               NaN
# 5386970          1          3             2                                 0
# 5386971          2          3             3                               NaN
# 5386972          2          3             3                               NaN
#
#          bucket_scoreacc_20250101_0830mnt bucket_scoreacc_20241201_0830mnt  \
# 0                                     NaN                              NaN
# 1                                     NaN                              NaN
# 2                                     NaN                              NaN
# 3                                      13                               13
# 4                                     NaN                              NaN
# ...                                   ...                              ...
# 5386968                               NaN                              NaN
# 5386969                               NaN                              NaN
# 5386970                               NaN                              NaN
# 5386971                               NaN                              NaN
# 5386972                               NaN                              NaN
#
#         bucket_scoreacc_20241101_0830mnt bucket_scoreacc_20241001_0830mnt  \
# 0                                    NaN                              NaN
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
# 3                                     13                               13
# 4                                    NaN                              NaN
# ...                                  ...                              ...
# 5386968                              NaN                              NaN
# 5386969                              NaN                              NaN
# 5386970                              NaN                              NaN
# 5386971                              NaN                              NaN
# 5386972                              NaN                              NaN
#
#         bucket_scoreacc_20240901_0830mnt avg_digit1
# 0                                    NaN        NaN
# 1                                    NaN        NaN
# 2                                    NaN        NaN
# 3                                    NaN        0.0
# 4                                    NaN        NaN
# ...                                  ...        ...
# 5386968                              NaN        NaN
# 5386969                              NaN        NaN
# 5386970                              NaN        0.0
# 5386971                              NaN        NaN
# 5386972                              NaN        NaN
#
# [5386973 rows x 22 columns]

# %%
files_tdr = glob.glob("./Input/ar_all/*.*")
files_tdr
# Out:
# ['./Input/ar_all\\AR_ALL_20250310_1.csv',
#  './Input/ar_all\\AR_ALL_20250310_2.csv',
#  './Input/ar_all\\TDR_ALL_LIST_FEB_2025.xlsx']

# %%
df_list = []  # Store individual DataFrames
for file in files_tdr:
    # print(f"Reading {file}...")
    path = glob.glob(f"{file}")[0].split('\\')[-1]
    # print(path)
    df = read_file('./input/ar_all/',path)
    df_list.append(df)
# Out:
# Encoding error with utf-8, trying another...
# c:\Users\Sireetron\automated\kbj_automation\99 Cscore\utils.py:41: DtypeWarning: Columns (9,63,71,72,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv(f'{pathfile}{filename}', encoding=enc)
# Successfully read AR_ALL_20250310_1.csv using ISO-8859-1 encoding.
# Encoding error with utf-8, trying another...
# c:\Users\Sireetron\automated\kbj_automation\99 Cscore\utils.py:41: DtypeWarning: Columns (10,60,71,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv(f'{pathfile}{filename}', encoding=enc)
# Successfully read AR_ALL_20250310_2.csv using ISO-8859-1 encoding.

# %%
data_tdr = pd.concat(df_list, ignore_index=True)
data_tdr = clean_column_names(data_tdr)
data_tdr['contract_no'] = data_tdr['contract_no'].astype(str).apply(lambda x: re.sub(r'\D', '', x))
data_tdr = data_tdr.loc[
    (data_tdr['product'] == 'TL') & 
    (
        data_tdr['project_code_name'].str.contains('ปรับโครงสร้าง', na=False) | 
        data_tdr['project_code_name'].str.contains('TDR', na=False) | 
        data_tdr['project_code_name'].str.contains('DR', na=False)
    )
].reset_index(drop=True)[['contract_no','project_code_name']]

# %%
data_cscore = data_all_digit.merge(data_tdr, left_on='contract_no', right_on='contract_no', how='left')
data_cscore
# Out:
#                       as_of_date       contract_no    customer_no  \
# 0        2025-03-19 00:00:00.000  5000161051018231  1110300202706
# 1        2025-03-19 00:00:00.000  1000161051042121  1110300202706
# 2        2025-03-19 00:00:00.000  5002461061050530  1110300203281
# 3        2025-03-19 00:00:00.000  5000361021006968  1110300205578
# 4        2025-03-19 00:00:00.000  5000461041075891  1110300208135
# ...                          ...               ...            ...
# 5386968  2025-03-19 00:00:00.000  7250170104680761  3800400714270
# 5386969  2025-03-19 00:00:00.000  7241270104483495  1301400032895
# 5386970  2025-03-19 00:00:00.000  7250170104615532  5361200029818
# 5386971  2025-03-19 00:00:00.000  7250170104600813  3720200607489
# 5386972  2025-03-19 00:00:00.000  7250170104600865  3730100965448
#
#          gross_income  occupation_type              occupation_name  \
# 0              9750.0              9.0        PRODUCTION LINE LABOR
# 1              9750.0              9.0        PRODUCTION LINE LABOR
# 2             10140.0              5.0                  OFFICE WORK
# 3              9300.0             10.0                GENERAL LABOR
# 4             13737.0              9.0        PRODUCTION LINE LABOR
# ...               ...              ...                          ...
# 5386968       12500.0              4.0               SPECIALIZATION
# 5386969       17500.0              5.0                  OFFICE WORK
# 5386970       50500.0              2.0  UNREGISTERED BUSINESS OWNER
# 5386971       17500.0              9.0        PRODUCTION LINE LABOR
# 5386972       50500.0              1.0    REGISTERED BUSINESS OWNER
#
#                    contract_date  contract_period   age  principal_bal  ...  \
# 0        2018-05-07 00:00:00.000             82.0  27.0           0.00  ...
# 1        2018-05-14 00:00:00.000             82.0  27.0         801.00  ...
# 2        2018-06-13 00:00:00.000             81.0  27.0           0.00  ...
# 3        2018-02-02 00:00:00.000             85.0  27.0       13890.67  ...
# 4        2018-04-26 00:00:00.000             82.0  27.0           0.00  ...
# ...                          ...              ...   ...            ...  ...
# 5386968  2025-01-31 00:00:00.000              1.0  41.0           0.00  ...
# 5386969  2024-12-28 00:00:00.000              2.0  39.0           0.00  ...
# 5386970  2025-01-19 00:00:00.000              2.0  59.0       24211.25  ...
# 5386971  2025-01-16 00:00:00.000              2.0  46.0           0.00  ...
# 5386972  2025-01-16 00:00:00.000              2.0  44.0           0.00  ...
#
#          digit2job  total_digit2  bucket_scoreacc_20250201_0830mnt  \
# 0                3             3                               NaN
# 1                3             3                               NaN
# 2                1             3                               NaN
# 3                2             3                                13
# 4                3             3                               NaN
# ...            ...           ...                               ...
# 5386968          1             2                               NaN
# 5386969          1             3                               NaN
# 5386970          3             2                                 0
# 5386971          3             3                               NaN
# 5386972          3             3                               NaN
#
#          bucket_scoreacc_20250101_0830mnt  bucket_scoreacc_20241201_0830mnt  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                      13                                13
# 4                                     NaN                               NaN
# ...                                   ...                               ...
# 5386968                               NaN                               NaN
# 5386969                               NaN                               NaN
# 5386970                               NaN                               NaN
# 5386971                               NaN                               NaN
# 5386972                               NaN                               NaN
#
#         bucket_scoreacc_20241101_0830mnt bucket_scoreacc_20241001_0830mnt  \
# 0                                    NaN                              NaN
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
# 3                                     13                               13
# 4                                    NaN                              NaN
# ...                                  ...                              ...
# 5386968                              NaN                              NaN
# 5386969                              NaN                              NaN
# 5386970                              NaN                              NaN
# 5386971                              NaN                              NaN
# 5386972                              NaN                              NaN
#
#         bucket_scoreacc_20240901_0830mnt avg_digit1 project_code_name
# 0                                    NaN        NaN               NaN
# 1                                    NaN        NaN               NaN
# 2                                    NaN        NaN               NaN
# 3                                    NaN        0.0               NaN
# 4                                    NaN        NaN               NaN
# ...                                  ...        ...               ...
# 5386968                              NaN        NaN               NaN
# 5386969                              NaN        NaN               NaN
# 5386970                              NaN        0.0               NaN
# 5386971                              NaN        NaN               NaN
# 5386972                              NaN        NaN               NaN
#
# [5386973 rows x 23 columns]

# %%
# Define conditions
conditions = [
    data_cscore['project_code_name'].notna(),      # A is not null
    data_cscore['mob'] < 7,          # A is less than 7
    data_cscore['avg_digit1'] > 3  ,
    data_cscore['avg_digit1'] > 1,# C is equal to 3
    data_cscore['avg_digit1'] >= 0,
]

# %%
# Define corresponding value
choices = ['H', 'D', 'H','M','L']
data_cscore['total_digit1']= np.select(conditions, choices, default='Other')
data_cscore['total_digit2'] = data_cscore['total_digit2'].map({3: 'H', 2: 'M', 1: 'L'})
data_cscore['final_score'] =data_cscore['total_digit1'].astype(str)+ data_cscore['total_digit2'].astype(str) +'0'+ data_cscore['mob'].astype(str)
data_cscore
# Out:
#                       as_of_date       contract_no    customer_no  \
# 0        2025-03-19 00:00:00.000  5000161051018231  1110300202706
# 1        2025-03-19 00:00:00.000  1000161051042121  1110300202706
# 2        2025-03-19 00:00:00.000  5002461061050530  1110300203281
# 3        2025-03-19 00:00:00.000  5000361021006968  1110300205578
# 4        2025-03-19 00:00:00.000  5000461041075891  1110300208135
# ...                          ...               ...            ...
# 5386968  2025-03-19 00:00:00.000  7250170104680761  3800400714270
# 5386969  2025-03-19 00:00:00.000  7241270104483495  1301400032895
# 5386970  2025-03-19 00:00:00.000  7250170104615532  5361200029818
# 5386971  2025-03-19 00:00:00.000  7250170104600813  3720200607489
# 5386972  2025-03-19 00:00:00.000  7250170104600865  3730100965448
#
#          gross_income  occupation_type              occupation_name  \
# 0              9750.0              9.0        PRODUCTION LINE LABOR
# 1              9750.0              9.0        PRODUCTION LINE LABOR
# 2             10140.0              5.0                  OFFICE WORK
# 3              9300.0             10.0                GENERAL LABOR
# 4             13737.0              9.0        PRODUCTION LINE LABOR
# ...               ...              ...                          ...
# 5386968       12500.0              4.0               SPECIALIZATION
# 5386969       17500.0              5.0                  OFFICE WORK
# 5386970       50500.0              2.0  UNREGISTERED BUSINESS OWNER
# 5386971       17500.0              9.0        PRODUCTION LINE LABOR
# 5386972       50500.0              1.0    REGISTERED BUSINESS OWNER
#
#                    contract_date  contract_period   age  principal_bal  ...  \
# 0        2018-05-07 00:00:00.000             82.0  27.0           0.00  ...
# 1        2018-05-14 00:00:00.000             82.0  27.0         801.00  ...
# 2        2018-06-13 00:00:00.000             81.0  27.0           0.00  ...
# 3        2018-02-02 00:00:00.000             85.0  27.0       13890.67  ...
# 4        2018-04-26 00:00:00.000             82.0  27.0           0.00  ...
# ...                          ...              ...   ...            ...  ...
# 5386968  2025-01-31 00:00:00.000              1.0  41.0           0.00  ...
# 5386969  2024-12-28 00:00:00.000              2.0  39.0           0.00  ...
# 5386970  2025-01-19 00:00:00.000              2.0  59.0       24211.25  ...
# 5386971  2025-01-16 00:00:00.000              2.0  46.0           0.00  ...
# 5386972  2025-01-16 00:00:00.000              2.0  44.0           0.00  ...
#
#          bucket_scoreacc_20250201_0830mnt  bucket_scoreacc_20250101_0830mnt  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                      13                                13
# 4                                     NaN                               NaN
# ...                                   ...                               ...
# 5386968                               NaN                               NaN
# 5386969                               NaN                               NaN
# 5386970                                 0                               NaN
# 5386971                               NaN                               NaN
# 5386972                               NaN                               NaN
#
#          bucket_scoreacc_20241201_0830mnt  bucket_scoreacc_20241101_0830mnt  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                      13                                13
# 4                                     NaN                               NaN
# ...                                   ...                               ...
# 5386968                               NaN                               NaN
# 5386969                               NaN                               NaN
# 5386970                               NaN                               NaN
# 5386971                               NaN                               NaN
# 5386972                               NaN                               NaN
#
#         bucket_scoreacc_20241001_0830mnt bucket_scoreacc_20240901_0830mnt  \
# 0                                    NaN                              NaN
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
# 3                                     13                              NaN
# 4                                    NaN                              NaN
# ...                                  ...                              ...
# 5386968                              NaN                              NaN
# 5386969                              NaN                              NaN
# 5386970                              NaN                              NaN
# 5386971                              NaN                              NaN
# 5386972                              NaN                              NaN
#
#         avg_digit1 project_code_name total_digit1 final_score
# 0              NaN               NaN        Other    OtherH07
# 1              NaN               NaN        Other    OtherH07
# 2              NaN               NaN        Other    OtherH07
# 3              0.0               NaN            L        LH07
# 4              NaN               NaN        Other    OtherH07
# ...            ...               ...          ...         ...
# 5386968        NaN               NaN            D        DM06
# 5386969        NaN               NaN            D        DH06
# 5386970        0.0               NaN            D        DM06
# 5386971        NaN               NaN            D        DH06
# 5386972        NaN               NaN            D        DH06
#
# [5386973 rows x 25 columns]

# %%
file_assign = glob.glob("./input/assign_data/*.xlsx")

# %%
data_assign = pd.read_excel(file_assign[0])
data_assign = clean_column_names(data_assign)
data_assign = data_assign[['contract_no','old_oa','new_oa','overdue_months_division_code']]
data_assign['contract_no'] = data_assign['contract_no'].astype(str)
data_assign
# Out:
#             contract_no         old_oa         new_oa  \
# 0      7220730100003250            KOR            KOR
# 1      7221030100003286            NaN  Delay calling
# 2      7230340100241933  Delay calling  Delay calling
# 3      7230530100570947            PCN            KOR
# 4      7230940101310936            NaN  Delay calling
# ...                 ...            ...            ...
# 40416  7240450102627362            KWC            KWC
# 40417  7240550102879930            GMV            MMN
# 40418  7240750103341461            KWC            KWC
# 40419  7240650103061703            MMN            KWC
# 40420  7240550102882336            MGC            KWC
#
#       overdue_months_division_code
# 0                      Grace_X-Day
# 1                      Grace_X-Day
# 2                      Grace_X-Day
# 3                              OD2
# 4                      Grace_X-Day
# ...                            ...
# 40416                          OD6
# 40417                          OD6
# 40418                          OD6
# 40419                          OD6
# 40420                          OD6
#
# [40421 rows x 4 columns]

# %% [markdown]
# ---

# %%
data_digit1['contract_no'] = data_digit1['contract_no'].astype(str)
data_performance['contract_no']= data_performance['contract_no'].astype(str)
data_performance
# Out:
#                       as_of_date       contract_no    customer_no  \
# 0        2025-03-19 00:00:00.000  5000161051018231  1110300202706
# 1        2025-03-19 00:00:00.000  1000161051042121  1110300202706
# 2        2025-03-19 00:00:00.000  5002461061050530  1110300203281
# 3        2025-03-19 00:00:00.000  5000361021006968  1110300205578
# 4        2025-03-19 00:00:00.000  5000461041075891  1110300208135
# ...                          ...               ...            ...
# 5386968  2025-03-19 00:00:00.000  7250170104680761  3800400714270
# 5386969  2025-03-19 00:00:00.000  7241270104483495  1301400032895
# 5386970  2025-03-19 00:00:00.000  7250170104615532  5361200029818
# 5386971  2025-03-19 00:00:00.000  7250170104600813  3720200607489
# 5386972  2025-03-19 00:00:00.000  7250170104600865  3730100965448
#
#          gross_income  occupation_type              occupation_name  \
# 0              9750.0              9.0        PRODUCTION LINE LABOR
# 1              9750.0              9.0        PRODUCTION LINE LABOR
# 2             10140.0              5.0                  OFFICE WORK
# 3              9300.0             10.0                GENERAL LABOR
# 4             13737.0              9.0        PRODUCTION LINE LABOR
# ...               ...              ...                          ...
# 5386968       12500.0              4.0               SPECIALIZATION
# 5386969       17500.0              5.0                  OFFICE WORK
# 5386970       50500.0              2.0  UNREGISTERED BUSINESS OWNER
# 5386971       17500.0              9.0        PRODUCTION LINE LABOR
# 5386972       50500.0              1.0    REGISTERED BUSINESS OWNER
#
#                    contract_date  contract_period   age  principal_bal  mob  \
# 0        2018-05-07 00:00:00.000             82.0  27.0           0.00    7
# 1        2018-05-14 00:00:00.000             82.0  27.0         801.00    7
# 2        2018-06-13 00:00:00.000             81.0  27.0           0.00    7
# 3        2018-02-02 00:00:00.000             85.0  27.0       13890.67    7
# 4        2018-04-26 00:00:00.000             82.0  27.0           0.00    7
# ...                          ...              ...   ...            ...  ...
# 5386968  2025-01-31 00:00:00.000              1.0  41.0           0.00    6
# 5386969  2024-12-28 00:00:00.000              2.0  39.0           0.00    6
# 5386970  2025-01-19 00:00:00.000              2.0  59.0       24211.25    6
# 5386971  2025-01-16 00:00:00.000              2.0  46.0           0.00    6
# 5386972  2025-01-16 00:00:00.000              2.0  44.0           0.00    6
#
#          digit2income  digit2age  digit2job  total_digit2
# 0                   3          3          3             3
# 1                   3          3          3             3
# 2                   3          3          1             3
# 3                   3          3          2             3
# 4                   3          3          3             3
# ...               ...        ...        ...           ...
# 5386968             3          2          1             2
# 5386969             3          3          1             3
# 5386970             2          1          3             2
# 5386971             3          2          3             3
# 5386972             2          2          3             3
#
# [5386973 rows x 15 columns]

# %%
data_performance.columns
# Out:
# Index(['as_of_date', 'contract_no', 'customer_no', 'gross_income',
#        'occupation_type', 'occupation_name', 'contract_no', 'contract_no',
#        'age', 'principal_bal', 'mob', 'digit2income', 'digit2age', 'digit2job',
#        'total_digit2'],
#       dtype='object')

# %%
data_digit1['avg_digit1'] = data_digit1.loc[:, data_digit1.columns.str.startswith('BUCKET_SCORE')].apply(pd.to_numeric, errors='coerce').sum(axis=1).fillna(0).astype(int)/6
data_all_digit = data_performance.merge(data_digit1, left_on='contract_no', right_on='contract_no', how='left', suffixes=('_df1', '_df2'))
data_all_digit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26440\88989027.py in ?()
#       1 data_digit1['avg_digit1'] = data_digit1.loc[:, data_digit1.columns.str.startswith('BUCKET_SCORE')].apply(pd.to_numeric, errors='coerce').sum(axis=1).fillna(0).astype(int)/6
# ----> 2 data_all_digit = data_performance.merge(data_digit1, left_on='contract_no', right_on='contract_no', how='left', suffixes=('_df1', '_df2'))
#       3 data_all_digit
#
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1306                     if lk is not None:
#    1307                         # Then we're either Hashable or a wrong-length arraylike,
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#    1313                         # work-around for merge_asof(left_index=True)
#
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1921             else:
#    1922                 multi_message = ""
#    1923
#    1924             label_axis_name = "column" if axis == 0 else "index"
# -> 1925             raise ValueError(
#    1926                 f"The {label_axis_name} label '{key}' is not unique.{multi_message}"
#    1927             )
#    1928
#
# ValueError: The column label 'contract_no' is not unique.

# %%
# data_all_digit['AVG_DIGIT1'] = data_all_digit.loc[:, data_all_digit.columns.str.startswith('SCORE_INDEX')].apply(pd.to_numeric, errors='coerce').mean(axis=1).fillna(0).astype(int)

data_all_digit['mob'] = pd.to_numeric(data_all_digit['mob'], errors='coerce').fillna(0).astype(int)
data_all_digit

# %%
for i in his[0:]:
    # print(f"Processing date: {i[0]}")
    print((i[0], i[1]))
    data = all_history(query,i[0], i[1])
    data_digit1 = data_digit1.merge(data, on='Loan No', how='left')
# Out:
# ('Acc_20250301_0830.csv', 'Acc_20250301_0830')
# ('Acc_20250201_0830.csv', 'Acc_20250201_0830')
# ('Acc_20250101_0830.csv', 'Acc_20250101_0830')
# ('Acc_20241201_0830.csv', 'Acc_20241201_0830')
# ('Acc_20241101_0830.csv', 'Acc_20241101_0830')
# c:\Users\Sireetron\automated\kbj_automation\Performance\utils.py:19: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_mnt = pd.read_csv(f'./input/acc_history_monthly/{date}')
# ('Acc_20241001_0830.csv', 'Acc_20241001_0830')
# c:\Users\Sireetron\automated\kbj_automation\Performance\utils.py:19: DtypeWarning: Columns (1,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_mnt = pd.read_csv(f'./input/acc_history_monthly/{date}')

# %%
data_digit1
# Out:
#                   Loan No SCORE_INDEXAcc_20250301_0830mnt  \
# 0        9010221122000949                               3
# 1        9010221122000931                               1
# 2        9010221122000922                               3
# 3        9010221122000914                               3
# 4        9010221122000906                               3
# ...                   ...                             ...
# 1372970  1000158090014831                               1
# 1372971  1000158090014814                               1
# 1372972  1000158090008580                               1
# 1372973  1000158090005394                               1
# 1372974  1000158080014811                               1
#
#         SCORE_INDEXAcc_20250201_0830mnt SCORE_INDEXAcc_20250101_0830mnt  \
# 0                                     3                               3
# 1                                     1                               1
# 2                                     3                               3
# 3                                     3                               3
# 4                                     3                               3
# ...                                 ...                             ...
# 1372970                               1                               1
# 1372971                               1                               1
# 1372972                               1                               1
# 1372973                               1                               1
# 1372974                               1                               1
#
#         SCORE_INDEXAcc_20241201_0830mnt SCORE_INDEXAcc_20241101_0830mnt  \
# 0                                     3                               3
# 1                                     1                               1
# 2                                     3                               3
# 3                                     3                               3
# 4                                     3                               3
# ...                                 ...                             ...
# 1372970                               1                               1
# 1372971                               1                               1
# 1372972                               1                               1
# 1372973                               1                               1
# 1372974                               1                               1
#
#         SCORE_INDEXAcc_20241001_0830mnt
# 0                                     3
# 1                                     1
# 2                                     3
# 3                                     3
# 4                                     3
# ...                                 ...
# 1372970                               1
# 1372971                               1
# 1372972                               1
# 1372973                               1
# 1372974                               1
#
# [1372975 rows x 7 columns]

# %%
# performane digit2
data_performance = pd.read_csv('./input/performance/performance.csv')
data_digit1['Loan No'] = data_digit1['Loan No'].astype(str)
data_performance['CONTRACT_NO']= data_performance['CONTRACT_NO'].astype(str)
data_digit1['AVG_DIGIT1'] = data_digit1.loc[:, data_digit1.columns.str.startswith('BUCKET_SCORE')].apply(pd.to_numeric, errors='coerce').sum(axis=1).fillna(0).astype(int)/6
data_all_digit = data_performance.merge(data_digit1, left_on='CONTRACT_NO', right_on='Loan No', how='left')
# data_all_digit['AVG_DIGIT1'] = data_all_digit.loc[:, data_all_digit.columns.str.startswith('SCORE_INDEX')].apply(pd.to_numeric, errors='coerce').mean(axis=1).fillna(0).astype(int)
data_all_digit['MOB'] = pd.to_numeric(data_all_digit['MOB'], errors='coerce').fillna(0).astype(int)
# Out:
# C:\Users\Sireetron\AppData\Local\Temp\ipykernel_16276\3607971684.py:2: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_performance = pd.read_csv('./input/performance/performance.csv')

# %%
data_performance
# Out:
#                       AS_OF_DATE       CONTRACT_NO    NATIONAL_ID  \
# 0        2025-03-09 00:00:00.000  5000160071029814  3450800190247
# 1        2025-03-09 00:00:00.000  7221140100022427  3601000365947
# 2        2025-03-09 00:00:00.000  7230950101266462  1709700073957
# 3        2025-03-09 00:00:00.000  5000161041003419  3300800674709
# 4        2025-03-09 00:00:00.000  7230410100429114  1401500153197
# ...                          ...               ...            ...
# 5323431  2025-03-09 00:00:00.000  7250270104792037  1720200122632
# 5323432  2025-03-09 00:00:00.000  7250370104881671  3650100771393
# 5323433  2025-03-09 00:00:00.000  7250370104881678  1200400034464
# 5323434  2025-03-09 00:00:00.000  7250270104729446  1679900263742
# 5323435  2025-03-09 00:00:00.000  7250270104729462  1349901334409
#
#          GROSS_INCOME  OCCUPATION_TYPE        OCCUPATION_NAME  \
# 0             10500.0             10.0          GENERAL LABOR
# 1             25763.0              9.0  PRODUCTION LINE LABOR
# 2             30000.0              5.0            OFFICE WORK
# 3             15611.0              9.0  PRODUCTION LINE LABOR
# 4             12224.0              9.0  PRODUCTION LINE LABOR
# ...               ...              ...                    ...
# 5323431       45000.0              4.0         SPECIALIZATION
# 5323432       17500.0              9.0  PRODUCTION LINE LABOR
# 5323433       35000.0              8.0            SERVICE JOB
# 5323434       45000.0              5.0            OFFICE WORK
# 5323435       17500.0              4.0         SPECIALIZATION
#
#                    CONTRACT_DATE  CONTRACT_PERIOD   AGE  PRINCIPAL_BAL  MOB  \
# 0        2017-07-17 00:00:00.000             91.0  48.0           0.00    7
# 1        2022-11-11 00:00:00.000             28.0  43.0       31783.61    7
# 2        2023-09-21 00:00:00.000             17.0  36.0       47052.21    7
# 3        2018-04-02 00:00:00.000             83.0  47.0           0.00    7
# 4        2023-04-25 00:00:00.000             22.0  30.0      274168.44    7
# ...                          ...              ...   ...            ...  ...
# 5323431  2025-02-16 00:00:00.000              0.0  29.0           0.00    6
# 5323432  2025-03-02 00:00:00.000              0.0  63.0           0.00    6
# 5323433  2025-03-02 00:00:00.000              0.0  36.0           0.00    6
# 5323434  2025-02-06 00:00:00.000              1.0  32.0       44944.74    6
# 5323435  2025-02-06 00:00:00.000              1.0  20.0       13955.90    6
#
#          DIGIT2INCOME  DIGIT2AGE  DIGIT2JOB  TOTAL_DIGIT2
# 0                   3          2          2             3
# 1                   3          2          3             3
# 2                   3          3          1             3
# 3                   3          2          3             3
# 4                   3          3          3             3
# ...               ...        ...        ...           ...
# 5323431             2          3          1             2
# 5323432             3          1          3             3
# 5323433             2          3          2             3
# 5323434             2          3          1             2
# 5323435             3          3          1             3
#
# [5323436 rows x 15 columns]

# %%
data_all_digit.columns
# Out:
# Index(['AS_OF_DATE', 'CONTRACT_NO', 'NATIONAL_ID', 'GROSS_INCOME',
#        'OCCUPATION_TYPE', 'OCCUPATION_NAME', 'CONTRACT_DATE',
#        'CONTRACT_PERIOD', 'AGE', 'PRINCIPAL_BAL', 'MOB', 'DIGIT2INCOME',
#        'DIGIT2AGE', 'DIGIT2JOB', 'TOTAL_DIGIT2', 'Loan No',
#        'SCORE_INDEXAcc_20250301_0830mnt', 'SCORE_INDEXAcc_20250201_0830mnt',
#        'SCORE_INDEXAcc_20250101_0830mnt', 'SCORE_INDEXAcc_20241201_0830mnt',
#        'SCORE_INDEXAcc_20241101_0830mnt', 'SCORE_INDEXAcc_20241001_0830mnt',
#        'AVG_DIGIT1'],
#       dtype='object')

# %%
# TDH digit2
files_tdr = glob.glob("./Input/ar_all/*.*")
print(f'file_files_tdr:, {files_tdr} ?? ')

df_list = []  # Store individual DataFrames
for file in files_tdr:
    # print(f"Reading {file}...")
    df = pd.read_csv(file, encoding='cp874', low_memory=False)
    df_list.append(df)
data_tdr = pd.concat(df_list, ignore_index=True)

data_tdr['Loan No'] = data_tdr['Loan No'].astype(str).apply(lambda x: re.sub(r'\D', '', x))
data_tdr = data_tdr.loc[
    (data_tdr['Product'] == 'TL') & 
    (
        data_tdr['Project Code Name'].str.contains('ปรับโครงสร้าง', na=False) | 
        data_tdr['Project Code Name'].str.contains('TDR', na=False) | 
        data_tdr['Project Code Name'].str.contains('DR', na=False)
    )
].reset_index(drop=True)[['Loan No','Project Code Name']]
# Out:
# file_files_tdr:, ['./Input/ar_all\\AR_ALL_20250310_1.csv', './Input/ar_all\\AR_ALL_20250310_2.csv'] ??

# %%
data_cscore = data_all_digit.merge(data_tdr, left_on='CONTRACT_NO', right_on='Loan No', how='left')

# %%
data_cscore
# Out:
#                       AS_OF_DATE       CONTRACT_NO    NATIONAL_ID  \
# 0        2025-03-09 00:00:00.000  5000160071029814  3450800190247
# 1        2025-03-09 00:00:00.000  7221140100022427  3601000365947
# 2        2025-03-09 00:00:00.000  7230950101266462  1709700073957
# 3        2025-03-09 00:00:00.000  5000161041003419  3300800674709
# 4        2025-03-09 00:00:00.000  7230410100429114  1401500153197
# ...                          ...               ...            ...
# 5323431  2025-03-09 00:00:00.000  7250270104792037  1720200122632
# 5323432  2025-03-09 00:00:00.000  7250370104881671  3650100771393
# 5323433  2025-03-09 00:00:00.000  7250370104881678  1200400034464
# 5323434  2025-03-09 00:00:00.000  7250270104729446  1679900263742
# 5323435  2025-03-09 00:00:00.000  7250270104729462  1349901334409
#
#          GROSS_INCOME  OCCUPATION_TYPE        OCCUPATION_NAME  \
# 0             10500.0             10.0          GENERAL LABOR
# 1             25763.0              9.0  PRODUCTION LINE LABOR
# 2             30000.0              5.0            OFFICE WORK
# 3             15611.0              9.0  PRODUCTION LINE LABOR
# 4             12224.0              9.0  PRODUCTION LINE LABOR
# ...               ...              ...                    ...
# 5323431       45000.0              4.0         SPECIALIZATION
# 5323432       17500.0              9.0  PRODUCTION LINE LABOR
# 5323433       35000.0              8.0            SERVICE JOB
# 5323434       45000.0              5.0            OFFICE WORK
# 5323435       17500.0              4.0         SPECIALIZATION
#
#                    CONTRACT_DATE  CONTRACT_PERIOD   AGE  PRINCIPAL_BAL  ...  \
# 0        2017-07-17 00:00:00.000             91.0  48.0           0.00  ...
# 1        2022-11-11 00:00:00.000             28.0  43.0       31783.61  ...
# 2        2023-09-21 00:00:00.000             17.0  36.0       47052.21  ...
# 3        2018-04-02 00:00:00.000             83.0  47.0           0.00  ...
# 4        2023-04-25 00:00:00.000             22.0  30.0      274168.44  ...
# ...                          ...              ...   ...            ...  ...
# 5323431  2025-02-16 00:00:00.000              0.0  29.0           0.00  ...
# 5323432  2025-03-02 00:00:00.000              0.0  63.0           0.00  ...
# 5323433  2025-03-02 00:00:00.000              0.0  36.0           0.00  ...
# 5323434  2025-02-06 00:00:00.000              1.0  32.0       44944.74  ...
# 5323435  2025-02-06 00:00:00.000              1.0  20.0       13955.90  ...
#
#                 Loan No_x  SCORE_INDEXAcc_20250301_0830mnt  \
# 0                     NaN                              NaN
# 1        7221140100022427                                3
# 2        7230950101266462                                2
# 3                     NaN                              NaN
# 4        7230410100429114                                3
# ...                   ...                              ...
# 5323431               NaN                              NaN
# 5323432               NaN                              NaN
# 5323433               NaN                              NaN
# 5323434  7250270104729446                                1
# 5323435  7250270104729462                                1
#
#          SCORE_INDEXAcc_20250201_0830mnt  SCORE_INDEXAcc_20250101_0830mnt  \
# 0                                    NaN                              NaN
# 1                                      3                                3
# 2                                      1                                1
# 3                                    NaN                              NaN
# 4                                      3                                3
# ...                                  ...                              ...
# 5323431                              NaN                              NaN
# 5323432                              NaN                              NaN
# 5323433                              NaN                              NaN
# 5323434                              NaN                              NaN
# 5323435                              NaN                              NaN
#
#          SCORE_INDEXAcc_20241201_0830mnt SCORE_INDEXAcc_20241101_0830mnt  \
# 0                                    NaN                             NaN
# 1                                      3                               3
# 2                                      3                               3
# 3                                    NaN                             NaN
# 4                                      3                               3
# ...                                  ...                             ...
# 5323431                              NaN                             NaN
# 5323432                              NaN                             NaN
# 5323433                              NaN                             NaN
# 5323434                              NaN                             NaN
# 5323435                              NaN                             NaN
#
#         SCORE_INDEXAcc_20241001_0830mnt AVG_DIGIT1         Loan No_y  \
# 0                                   NaN        NaN               NaN
# 1                                     3        0.0               NaN
# 2                                     3        0.0  7230950101266462
# 3                                   NaN        NaN               NaN
# 4                                     3        0.0               NaN
# ...                                 ...        ...               ...
# 5323431                             NaN        NaN               NaN
# 5323432                             NaN        NaN               NaN
# 5323433                             NaN        NaN               NaN
# 5323434                             NaN        0.0               NaN
# 5323435                             NaN        0.0               NaN
#
#                            Project Code Name
# 0                                        NaN
# 1                                        NaN
# 2        ปรับโครงสร้างหนี้_DR_Collection_15%
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 5323431                                  NaN
# 5323432                                  NaN
# 5323433                                  NaN
# 5323434                                  NaN
# 5323435                                  NaN
#
# [5323436 rows x 25 columns]

# %%
data_cscore['AVG_DIGIT1']
# Out:
# 0          NaN
# 1          0.0
# 2          0.0
# 3          NaN
# 4          0.0
#           ...
# 5323431    NaN
# 5323432    NaN
# 5323433    NaN
# 5323434    0.0
# 5323435    0.0
# Name: AVG_DIGIT1, Length: 5323436, dtype: float64
