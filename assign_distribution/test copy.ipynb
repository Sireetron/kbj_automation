# %%
import pandas as pd
import glob
import numpy as np
import pandas as pd
import glob
import jaydebeapi
import re

# %%
import pandas as pd
import glob
import numpy as np
import re
from utils import read_file,clean_column_names,assign_to_oa
pd.set_option('display.float_format', '{:.0f}'.format)

# %%
assigned_path  = glob.glob("./input/assigned/*") 
assigned_path[0]
# Out:
# './input/assigned\\oa_proportion.xlsx'

# %%
glob.glob("./input/assigned/*")[0].split('\\')[-1]
# Out:
# 'oa_proportion.xlsx'

# %%
assigned_path  = glob.glob("./input/assigned/*")[0].split('\\')[-1]
assigned_path
# Out:
# 'oa_proportion.xlsx'

# %%
pd.set_option('display.float_format', '{:.0f}'.format)

# %%
oa_proportion = read_file('./input/assigned/',assigned_path)
oa_proportion
# Out:
#      Product                            Bucket  %Assign        OA  group  \
# 0        H4C                              XDAY        1  In-House      1
# 1        H4C                           OD1-OD2        1       JMT      2
# 2        C4C  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL        1       DHA      3
# 3        C4C  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL        0       PCN      3
# 4     SFLoan                             X-DAY        1  In-House      4
# 5     SFLoan                           OD1-OD2        1  In-House      5
# 6     SFLoan                   OD3-OD4-OD5-OD6        0       LBR      6
# 7     SFLoan                   OD3-OD4-OD5-OD6        0      THAS      6
# 8     SFLoan                   OD3-OD4-OD5-OD6        0       WSP      6
# 9     SFLoan                   OD3-OD4-OD5-OD6        0       ASJ      6
# 10    SFLoan                   OD3-OD4-OD5-OD6        0       PCN      6
# 11    SFLoan                   OD3-OD4-OD5-OD6        0       UPC      6
# 12  RL ML TL                      XDAY-OD1-OD2        0       PCN      7
# 13  RL ML TL                      XDAY-OD1-OD2        0       ACT      7
# 14  RL ML TL                      XDAY-OD1-OD2        0  In-House      7
# 15  RL ML TL                      XDAY-OD1-OD2        0       DHA      7
# 16  RL ML TL                      XDAY-OD1-OD2        0       KOR      7
# 17  RL ML TL                      XDAY-OD1-OD2        0       KWC      7
# 18  RL ML TL                      XDAY-OD1-OD2        0       MMN      7
# 19  RL ML TL                   OD3-OD4-OD5-OD6        0       KWC      8
# 20  RL ML TL                   OD3-OD4-OD5-OD6        0       MMN      8
# 21  RL ML TL                   OD3-OD4-OD5-OD6        0       GMV      8
# 22  RL ML TL                   OD3-OD4-OD5-OD6        0       UPC      8
#
#               assign_type
# 0              assign_all
# 1              assign_all
# 2     save_old_assign_new
# 3     save_old_assign_new
# 4              assign_all
# 5              assign_all
# 6     save_old_assign_new
# 7     save_old_assign_new
# 8     save_old_assign_new
# 9     save_old_assign_new
# 10    save_old_assign_new
# 11    save_old_assign_new
# 12  assign_old_assign_new
# 13  assign_old_assign_new
# 14  assign_old_assign_new
# 15  assign_old_assign_new
# 16  assign_old_assign_new
# 17  assign_old_assign_new
# 18  assign_old_assign_new
# 19    save_old_assign_new
# 20    save_old_assign_new
# 21    save_old_assign_new
# 22    save_old_assign_new

# %%
oa_proportion = clean_column_names(oa_proportion)

# %%
map_criteria = oa_proportion[['product','bucket','group','assign_type']].drop_duplicates(subset=['product', 'bucket','group','assign_type'])

# %%
ar_path = glob.glob("./input/AR/*")[0].split('\\')[-1] 
ar = read_file('./input/AR/',ar_path)
ar = clean_column_names(ar)

# %%
ar
# Out:
#       base_date  customer_no    customer_no  principal_balance  \
# 0      02-04-68  14220001105  1189900322662               1329
# 1      02-04-68  14220134943  3100202287312               1246
# 2      02-04-68  14220154491  3400600541658                539
# 3      02-04-68  14220137826  1800600148549                547
# 4      02-04-68  14220144883  3102002143718               1560
# ...         ...          ...            ...                ...
# 24789  02-04-68  14231185266  1419901887938              10467
# 24790  02-04-68  14242910960  1849901381763               5981
# 24791  02-04-68  14242387135  1199600053615               5981
# 24792  02-04-68  14230817713  3841500429420              14952
# 24793  02-04-68  14242878881  3440800956053               5981
#
#        total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 0                      NaN                     1446                     91
# 1                      NaN                     1355                     91
# 2                      NaN                      586                     91
# 3                      NaN                      595                     91
# 4                      NaN                     1698                     91
# ...                    ...                      ...                    ...
# 24789                  NaN                     5537                    183
# 24790                  NaN                     4623                    183
# 24791                  NaN                     4623                    183
# 24792                  NaN                     7746                    183
# 24793                  NaN                     4623                    183
#
#        overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 0                         4            91                      4  ...
# 1                         4            91                      4  ...
# 2                         4            91                      4  ...
# 3                         4            91                      4  ...
# 4                         4            91                      4  ...
# ...                     ...           ...                    ...  ...
# 24789                     7           183                      7  ...
# 24790                     7           183                      7  ...
# 24791                     7           183                      7  ...
# 24792                     7           183                      7  ...
# 24793                     7           183                      7  ...
#
#                           occupation sales_product_code1  \
# 0            9:PRODUCTION LINE LABOR         A701:SFLoan
# 1                            6:SALES         A701:SFLoan
# 2                      5:OFFICE WORK         A701:SFLoan
# 3            9:PRODUCTION LINE LABOR         A701:SFLoan
# 4                      5:OFFICE WORK         A701:SFLoan
# ...                              ...                 ...
# 24789                        6:SALES         A701:SFLoan
# 24790                        6:SALES         A701:SFLoan
# 24791               4:SPECIALIZATION         A701:SFLoan
# 24792  2:UNREGISTERED BUSINESS OWNER         A701:SFLoan
# 24793               10:GENERAL LABOR         A701:SFLoan
#
#       waived_processing_amt(xday)  extend_term_changed_count ever  product  \
# 0                               0                          0    N      SF+
# 1                               0                          0    N      SF+
# 2                               0                          0    N      SF+
# 3                               0                          0    N      SF+
# 4                               0                          0    N      SF+
# ...                           ...                        ...  ...      ...
# 24789                           0                          0    N      SF+
# 24790                           0                          0    N      SF+
# 24791                           0                          0    N      SF+
# 24792                           0                          0    N      SF+
# 24793                           0                          0    N      SF+
#
#        status_lm    old_oa  new_oa c_score
# 0         UNSAVE  In-House     NaN     NaN
# 1         UNSAVE  In-House     NaN     NaN
# 2         UNSAVE  In-House     NaN     NaN
# 3         UNSAVE  In-House     NaN     NaN
# 4         UNSAVE  In-House     NaN     NaN
# ...          ...       ...     ...     ...
# 24789     UNSAVE       LBR     NaN     NaN
# 24790     UNSAVE       ASJ     NaN     NaN
# 24791     UNSAVE       WSP     NaN     NaN
# 24792     UNSAVE       MGC     NaN     NaN
# 24793     UNSAVE      THAS     NaN     NaN
#
# [24794 rows x 85 columns]

# %%
def read_file(pathfile,filename):
    if filename:
        if filename.endswith(".xlsx"):
            file = pd.read_excel(f'{pathfile}{filename}', dtype={'%Assign': float})
        elif filename.endswith(".csv"):
            file = pd.read_csv(f'{pathfile}{filename}')
        return file  
    # print(assign.head())  # Display first few rows
    else:
        print("No file found in the folder.")

# %%
oa_proportion['%assign'] = oa_proportion['%assign'].apply(lambda x: "{:.2f}".format(x) if pd.notna(x) else "NaN")

# %%
oa_proportion
# Out:
#      product                            bucket %assign        oa  group  \
# 0        H4C                              XDAY    1.00  In-House      1
# 1        H4C                           OD1-OD2    1.00       JMT      2
# 2        C4C  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL    0.60       DHA      3
# 3        C4C  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL    0.40       PCN      3
# 4     SFLoan                             X-DAY    1.00  In-House      4
# 5     SFLoan                           OD1-OD2    1.00  In-House      5
# 6     SFLoan                   OD3-OD4-OD5-OD6    0.20       LBR      6
# 7     SFLoan                   OD3-OD4-OD5-OD6    0.18      THAS      6
# 8     SFLoan                   OD3-OD4-OD5-OD6    0.17       WSP      6
# 9     SFLoan                   OD3-OD4-OD5-OD6    0.16       ASJ      6
# 10    SFLoan                   OD3-OD4-OD5-OD6    0.15       PCN      6
# 11    SFLoan                   OD3-OD4-OD5-OD6    0.14       UPC      6
# 12  RL ML TL                      XDAY-OD1-OD2    0.20       PCN      7
# 13  RL ML TL                      XDAY-OD1-OD2    0.19       ACT      7
# 14  RL ML TL                      XDAY-OD1-OD2    0.14  In-House      7
# 15  RL ML TL                      XDAY-OD1-OD2    0.17       DHA      7
# 16  RL ML TL                      XDAY-OD1-OD2    0.12       KOR      7
# 17  RL ML TL                      XDAY-OD1-OD2    0.08       KWC      7
# 18  RL ML TL                      XDAY-OD1-OD2    0.10       MMN      7
# 19  RL ML TL                   OD3-OD4-OD5-OD6    0.32       KWC      8
# 20  RL ML TL                   OD3-OD4-OD5-OD6    0.27       MMN      8
# 21  RL ML TL                   OD3-OD4-OD5-OD6    0.23       GMV      8
# 22  RL ML TL                   OD3-OD4-OD5-OD6    0.18       UPC      8
#
#               assign_type
# 0              assign_all
# 1              assign_all
# 2     save_old_assign_new
# 3     save_old_assign_new
# 4              assign_all
# 5              assign_all
# 6     save_old_assign_new
# 7     save_old_assign_new
# 8     save_old_assign_new
# 9     save_old_assign_new
# 10    save_old_assign_new
# 11    save_old_assign_new
# 12  assign_old_assign_new
# 13  assign_old_assign_new
# 14  assign_old_assign_new
# 15  assign_old_assign_new
# 16  assign_old_assign_new
# 17  assign_old_assign_new
# 18  assign_old_assign_new
# 19    save_old_assign_new
# 20    save_old_assign_new
# 21    save_old_assign_new
# 22    save_old_assign_new

# %%
ar['product_val'] =  ar['sales_product_code'].str.extract(r':\s*(.*)').replace(r'\b(RL|ML|TL)\b', 'RL ML TL', regex=True)

# %%
ar.groupby('product_val').size()
# Out:
# product_val
# SFLoan    24794
# dtype: int64

# %%
map_criteria
# Out:
#      product                            bucket  group            assign_type
# 0        H4C                              XDAY      1             assign_all
# 1        H4C                           OD1-OD2      2             assign_all
# 2        C4C  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3    save_old_assign_new
# 4     SFLoan                             X-DAY      4             assign_all
# 5     SFLoan                           OD1-OD2      5             assign_all
# 6     SFLoan                   OD3-OD4-OD5-OD6      6    save_old_assign_new
# 12  RL ML TL                      XDAY-OD1-OD2      7  assign_old_assign_new
# 19  RL ML TL                   OD3-OD4-OD5-OD6      8    save_old_assign_new

# %%
ar
# Out:
#       base_date  customer_no    customer_no  principal_balance  \
# 0      02-04-68  14220001105  1189900322662               1329
# 1      02-04-68  14220134943  3100202287312               1246
# 2      02-04-68  14220154491  3400600541658                539
# 3      02-04-68  14220137826  1800600148549                547
# 4      02-04-68  14220144883  3102002143718               1560
# ...         ...          ...            ...                ...
# 24789  02-04-68  14231185266  1419901887938              10467
# 24790  02-04-68  14242910960  1849901381763               5981
# 24791  02-04-68  14242387135  1199600053615               5981
# 24792  02-04-68  14230817713  3841500429420              14952
# 24793  02-04-68  14242878881  3440800956053               5981
#
#        total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 0                      NaN                     1446                     91
# 1                      NaN                     1355                     91
# 2                      NaN                      586                     91
# 3                      NaN                      595                     91
# 4                      NaN                     1698                     91
# ...                    ...                      ...                    ...
# 24789                  NaN                     5537                    183
# 24790                  NaN                     4623                    183
# 24791                  NaN                     4623                    183
# 24792                  NaN                     7746                    183
# 24793                  NaN                     4623                    183
#
#        overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 0                         4            91                      4  ...
# 1                         4            91                      4  ...
# 2                         4            91                      4  ...
# 3                         4            91                      4  ...
# 4                         4            91                      4  ...
# ...                     ...           ...                    ...  ...
# 24789                     7           183                      7  ...
# 24790                     7           183                      7  ...
# 24791                     7           183                      7  ...
# 24792                     7           183                      7  ...
# 24793                     7           183                      7  ...
#
#       sales_product_code1 waived_processing_amt(xday)  \
# 0             A701:SFLoan                           0
# 1             A701:SFLoan                           0
# 2             A701:SFLoan                           0
# 3             A701:SFLoan                           0
# 4             A701:SFLoan                           0
# ...                   ...                         ...
# 24789         A701:SFLoan                           0
# 24790         A701:SFLoan                           0
# 24791         A701:SFLoan                           0
# 24792         A701:SFLoan                           0
# 24793         A701:SFLoan                           0
#
#       extend_term_changed_count  ever product  status_lm    old_oa new_oa  \
# 0                             0     N     SF+     UNSAVE  In-House    NaN
# 1                             0     N     SF+     UNSAVE  In-House    NaN
# 2                             0     N     SF+     UNSAVE  In-House    NaN
# 3                             0     N     SF+     UNSAVE  In-House    NaN
# 4                             0     N     SF+     UNSAVE  In-House    NaN
# ...                         ...   ...     ...        ...       ...    ...
# 24789                         0     N     SF+     UNSAVE       LBR    NaN
# 24790                         0     N     SF+     UNSAVE       ASJ    NaN
# 24791                         0     N     SF+     UNSAVE       WSP    NaN
# 24792                         0     N     SF+     UNSAVE       MGC    NaN
# 24793                         0     N     SF+     UNSAVE      THAS    NaN
#
#        c_score product_val
# 0          NaN      SFLoan
# 1          NaN      SFLoan
# 2          NaN      SFLoan
# 3          NaN      SFLoan
# 4          NaN      SFLoan
# ...        ...         ...
# 24789      NaN      SFLoan
# 24790      NaN      SFLoan
# 24791      NaN      SFLoan
# 24792      NaN      SFLoan
# 24793      NaN      SFLoan
#
# [24794 rows x 86 columns]

# %%
ar_merge = ar.merge(map_criteria,left_on='product_val',right_on = 'product', suffixes=('_df1', '_df2'))

# %%
ar_merge
# Out:
#       base_date  customer_no    customer_no  principal_balance  \
# 0      02-04-68  14220001105  1189900322662               1329
# 1      02-04-68  14220001105  1189900322662               1329
# 2      02-04-68  14220001105  1189900322662               1329
# 3      02-04-68  14220134943  3100202287312               1246
# 4      02-04-68  14220134943  3100202287312               1246
# ...         ...          ...            ...                ...
# 74377  02-04-68  14230817713  3841500429420              14952
# 74378  02-04-68  14230817713  3841500429420              14952
# 74379  02-04-68  14242878881  3440800956053               5981
# 74380  02-04-68  14242878881  3440800956053               5981
# 74381  02-04-68  14242878881  3440800956053               5981
#
#        total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 0                      NaN                     1446                     91
# 1                      NaN                     1446                     91
# 2                      NaN                     1446                     91
# 3                      NaN                     1355                     91
# 4                      NaN                     1355                     91
# ...                    ...                      ...                    ...
# 74377                  NaN                     7746                    183
# 74378                  NaN                     7746                    183
# 74379                  NaN                     4623                    183
# 74380                  NaN                     4623                    183
# 74381                  NaN                     4623                    183
#
#        overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 0                         4            91                      4  ...
# 1                         4            91                      4  ...
# 2                         4            91                      4  ...
# 3                         4            91                      4  ...
# 4                         4            91                      4  ...
# ...                     ...           ...                    ...  ...
# 74377                     7           183                      7  ...
# 74378                     7           183                      7  ...
# 74379                     7           183                      7  ...
# 74380                     7           183                      7  ...
# 74381                     7           183                      7  ...
#
#       product_df1 status_lm    old_oa  new_oa c_score  product_val  \
# 0             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 1             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 2             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 3             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 4             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# ...           ...       ...       ...     ...     ...          ...
# 74377         SF+    UNSAVE       MGC     NaN     NaN       SFLoan
# 74378         SF+    UNSAVE       MGC     NaN     NaN       SFLoan
# 74379         SF+    UNSAVE      THAS     NaN     NaN       SFLoan
# 74380         SF+    UNSAVE      THAS     NaN     NaN       SFLoan
# 74381         SF+    UNSAVE      THAS     NaN     NaN       SFLoan
#
#        product_df2           bucket  group          assign_type
# 0           SFLoan            X-DAY      4           assign_all
# 1           SFLoan          OD1-OD2      5           assign_all
# 2           SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 3           SFLoan            X-DAY      4           assign_all
# 4           SFLoan          OD1-OD2      5           assign_all
# ...            ...              ...    ...                  ...
# 74377       SFLoan          OD1-OD2      5           assign_all
# 74378       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 74379       SFLoan            X-DAY      4           assign_all
# 74380       SFLoan          OD1-OD2      5           assign_all
# 74381       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
#
# [74382 rows x 90 columns]

# %%
ar_merge.columns
# Out:
# Index(['base_date', 'customer_no', 'customer_no', 'principal_balance',
#        'total_unclaimed_amt', 'repayment_target_amount',
#        'overdue_days(morning)', 'overdue_cnt(morning)', 'overdue_days',
#        'num_of_overdue_months', 'overdue_months_division_code', 'corp_info',
#        'sales_product_code', 'contract_no', 'customer_name', 'customer_no',
#        'mobile_no', 'address(home)', 'post_code', 'phone_no(home)',
#        'address(office)', 'post_code1', 'biz_phone_no',
#        'address_(place_of_residence)', 'post_code', 'phone_no',
#        'delivery_address', 'post_code2', 'delivery_phone_no',
#        'customer_relationship', 'related_person', 'phone_no_1',
#        'customer_relationship1', 'related_person1', 'phone_no_2',
#        'branch_code', 'outstanding_balance', 'loan_date', 'installment_count',
#        'product_name', 'last_money_received_date', 'last_payment_amt',
#        'loan_amt', 'principal', 'monthly_payment_amt', 'first_settlement_date',
#        'last_payment_date', 'billing_interest_amt',
#        'billing_credit_usage_amount', 'overdue_start_date', 'overdue_int',
#        'overdue_credit_usage_amount', 'collection_fee', 'overdue_sum_amt',
#        'overdue_months_division_code1', 'dob', 'marital_status', 'phone_no_3',
#        'company_name', 'company_extension_no', 'headquarter_phone_no',
#        'headquarter_extension_no', 'monthly_income', 'email_address',
#        'next_payment_due_date', 'next_payment_amt', 'payment_date',
#        'total_count', 'number_of_deposit_on_1st_of_month',
#        'number_of_deposit_on/before_5th_of_month',
#        'number_of_deposit_before_24th_of_month',
#        'number_of_deposit_before_25th_of_month',
#        'number_of_deposit_at_the_end_of_month', 'last_payment_amt1',
#        'biz_industry_code', 'occupation', 'sales_product_code1',
#        'waived_processing_amt(xday)', 'extend_term_changed_count', 'ever',
#        'product_df1', 'status_lm', 'old_oa', 'new_oa', 'c_score',
#        'product_val', 'product_df2', 'bucket', 'group', 'assign_type'],
#       dtype='object')

# %%
ar_merge  = ar_merge[ar_merge.apply(lambda row: row['overdue_months_division_code'] in row['bucket'], axis=1)]

# %%
ar_merge
# Out:
#       base_date  customer_no    customer_no  principal_balance  \
# 2      02-04-68  14220001105  1189900322662               1329
# 5      02-04-68  14220134943  3100202287312               1246
# 8      02-04-68  14220154491  3400600541658                539
# 11     02-04-68  14220137826  1800600148549                547
# 14     02-04-68  14220144883  3102002143718               1560
# ...         ...          ...            ...                ...
# 74369  02-04-68  14231185266  1419901887938              10467
# 74372  02-04-68  14242910960  1849901381763               5981
# 74375  02-04-68  14242387135  1199600053615               5981
# 74378  02-04-68  14230817713  3841500429420              14952
# 74381  02-04-68  14242878881  3440800956053               5981
#
#        total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 2                      NaN                     1446                     91
# 5                      NaN                     1355                     91
# 8                      NaN                      586                     91
# 11                     NaN                      595                     91
# 14                     NaN                     1698                     91
# ...                    ...                      ...                    ...
# 74369                  NaN                     5537                    183
# 74372                  NaN                     4623                    183
# 74375                  NaN                     4623                    183
# 74378                  NaN                     7746                    183
# 74381                  NaN                     4623                    183
#
#        overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 2                         4            91                      4  ...
# 5                         4            91                      4  ...
# 8                         4            91                      4  ...
# 11                        4            91                      4  ...
# 14                        4            91                      4  ...
# ...                     ...           ...                    ...  ...
# 74369                     7           183                      7  ...
# 74372                     7           183                      7  ...
# 74375                     7           183                      7  ...
# 74378                     7           183                      7  ...
# 74381                     7           183                      7  ...
#
#       product_df1 status_lm    old_oa  new_oa c_score  product_val  \
# 2             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 5             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 8             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 11            SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 14            SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# ...           ...       ...       ...     ...     ...          ...
# 74369         SF+    UNSAVE       LBR     NaN     NaN       SFLoan
# 74372         SF+    UNSAVE       ASJ     NaN     NaN       SFLoan
# 74375         SF+    UNSAVE       WSP     NaN     NaN       SFLoan
# 74378         SF+    UNSAVE       MGC     NaN     NaN       SFLoan
# 74381         SF+    UNSAVE      THAS     NaN     NaN       SFLoan
#
#        product_df2           bucket  group          assign_type
# 2           SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 5           SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 8           SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 11          SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 14          SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# ...            ...              ...    ...                  ...
# 74369       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 74372       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 74375       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 74378       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 74381       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
#
# [24794 rows x 90 columns]

# %%
def split_dataframe_by_group(df, group_column, prefix):
    # Get unique values in the specified group column
    unique_values = df[group_column].unique()
    
    # Create a list to store the names of the created DataFrames
    dataframe_names = []
    
    # Create separate dataframes for each unique value in the group column
    for value in unique_values:
        df_name = f"{prefix}_{value}"
        globals()[df_name] = df[df[group_column] == value]
        dataframe_names.append(df_name)
    
    # Print the name of each created dataframe
    # for df_name in dataframe_names:
        # print(f"Dataframe name: {df_name}")
        # Uncomment the next line to print the dataframe contents
        # print(globals()[df_name], "\n")
    
    # Return the list of DataFrame names
    return dataframe_names

# %%
oa_proportion
# Out:
#      product                            bucket %assign        oa  group  \
# 0        H4C                              XDAY    1.00  In-House      1
# 1        H4C                           OD1-OD2    1.00       JMT      2
# 2        C4C  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL    0.60       DHA      3
# 3        C4C  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL    0.40       PCN      3
# 4     SFLoan                             X-DAY    1.00  In-House      4
# 5     SFLoan                           OD1-OD2    1.00  In-House      5
# 6     SFLoan                   OD3-OD4-OD5-OD6    0.20       LBR      6
# 7     SFLoan                   OD3-OD4-OD5-OD6    0.18      THAS      6
# 8     SFLoan                   OD3-OD4-OD5-OD6    0.17       WSP      6
# 9     SFLoan                   OD3-OD4-OD5-OD6    0.16       ASJ      6
# 10    SFLoan                   OD3-OD4-OD5-OD6    0.15       PCN      6
# 11    SFLoan                   OD3-OD4-OD5-OD6    0.14       UPC      6
# 12  RL ML TL                      XDAY-OD1-OD2    0.20       PCN      7
# 13  RL ML TL                      XDAY-OD1-OD2    0.19       ACT      7
# 14  RL ML TL                      XDAY-OD1-OD2    0.14  In-House      7
# 15  RL ML TL                      XDAY-OD1-OD2    0.17       DHA      7
# 16  RL ML TL                      XDAY-OD1-OD2    0.12       KOR      7
# 17  RL ML TL                      XDAY-OD1-OD2    0.08       KWC      7
# 18  RL ML TL                      XDAY-OD1-OD2    0.10       MMN      7
# 19  RL ML TL                   OD3-OD4-OD5-OD6    0.32       KWC      8
# 20  RL ML TL                   OD3-OD4-OD5-OD6    0.27       MMN      8
# 21  RL ML TL                   OD3-OD4-OD5-OD6    0.23       GMV      8
# 22  RL ML TL                   OD3-OD4-OD5-OD6    0.18       UPC      8
#
#               assign_type
# 0              assign_all
# 1              assign_all
# 2     save_old_assign_new
# 3     save_old_assign_new
# 4              assign_all
# 5              assign_all
# 6     save_old_assign_new
# 7     save_old_assign_new
# 8     save_old_assign_new
# 9     save_old_assign_new
# 10    save_old_assign_new
# 11    save_old_assign_new
# 12  assign_old_assign_new
# 13  assign_old_assign_new
# 14  assign_old_assign_new
# 15  assign_old_assign_new
# 16  assign_old_assign_new
# 17  assign_old_assign_new
# 18  assign_old_assign_new
# 19    save_old_assign_new
# 20    save_old_assign_new
# 21    save_old_assign_new
# 22    save_old_assign_new

# %%
def assign_to_oa(df_toassign) : 
    # print('df_toassign',len(df_toassign))
    # List to store the concatenated dataframes
    oa_list = split_dataframe_by_group(oa_proportion, 'group', 'oa')
    ar_list = split_dataframe_by_group(df_toassign, 'group', 'ar')
    # print(ar_list)
    dataframes_oa = {name: globals()[name] for name in oa_list}
    dataframes_ar = {name: globals()[name] for name in ar_list}
    combined_dfs = []

    # Iterate through each ar dataframe in dataframes_ar
    for i in dataframes_ar:
        ar_df = dataframes_ar[i]
        # print(i)
        # print(ar_df)

        order = i[-1]  # Extract the last character of the first element for 'order'
        # print('order', order)
        
        # df_y = ar_df.loc[ar_df['ever'] == 'Y']  # Filter rows where 'ever' == 'Y'
        # df_n = ar_df.loc[ar_df['ever'] == 'N']  # Filter rows where 'ever' == 'N'
        
        size = ar_df['contract_no'].count()  # Count of 'Y' contracts
        # size_n = df_n['contract_no'].count()  # Count of 'N' contracts
        
        # Get the corresponding OA dataframe based on order
        oa = dataframes_oa[f'oa_{order}']
        
        # Assign values randomly based on the OA assignment probabilities
        ar_df['assigned'] = np.random.choice(oa['oa'], size=size, p=oa['%assign'])
        # df_n['assigned'] = np.random.choice(oa['oa'], size=size_n, p=oa['%assign'])
        
        # Combine the 'Y' and 'N' dataframes
        assigned_df = ar_df
        
        # Store the concatenated dataframe in the list
        combined_dfs.append(assigned_df)

    # Concatenate all the combined dataframes into one final dataframe
    final_df = pd.concat(combined_dfs, ignore_index=True)

    # Optionally, assign the final concatenated dataframe to a dynamic variable
    globals()['df_assign_all'] = final_df

    # Print the final dataframe
    # print(final_df)
    return final_df

# %% [markdown]
# ---

# %%
def splitassign(sorted_df):
    """
    Splits the input DataFrame into smaller DataFrames based on record count,
    assigns values using assign_to_oa, and merges the results.
    """
    if sorted_df.empty:  # Handle empty DataFrame case
        return pd.DataFrame()

    num_records = len(sorted_df)
    
    if num_records < 50:
        split_count = 1  # No split
    elif num_records < 200:
        split_count = 5
    else:
        split_count = 12
    
    split_dfs = np.array_split(sorted_df, split_count)
    
    updated_dfs = [assign_to_oa(split_df) for split_df in split_dfs if not split_df.empty]

    return pd.concat(updated_dfs, ignore_index=True) if updated_dfs else pd.DataFrame()

# Initialize merged_df before loop
merged_df = pd.DataFrame()

# %%
loop_test = assign_new['overdue_months_division_code'].unique()

# %%
import numpy as np
import pandas as pd

  # Initialize an empty DataFrame

for i in loop_test:
    subset = assign_new[assign_new['overdue_months_division_code'] == i]
    
    df_y = subset[subset['ever'] == 'Y'].sort_values(by='principal_balance', ascending=False)
    # print('df_y',df_y)
    df_n = subset[subset['ever'] == 'N'].sort_values(by='principal_balance', ascending=False)
    # print('df_n',df_n)
    
    
    df_assign_y = splitassign(df_y)
    df_assign_n = splitassign(df_n)
    assigned_df = pd.concat([df_assign_y, df_assign_n], ignore_index=True)
    merged_df = pd.concat([merged_df, assigned_df], ignore_index=True)
# Out:
# df_y        base_date  customer_no    customer_no  principal_balance  \
# 41    02-03-2568  12180051412  3730200338275             324387
# 2518  02-03-2568  14220004845  1200100332974             186653
# 4652  02-03-2568  14220059196  3102101769658             157997
# 1907  02-03-2568  14220100712  1269900185923             148162
# 39    02-03-2568  12180044964  3341700320558             142817
# ...          ...          ...            ...                ...
# 4988  02-03-2568  13200002086  3860400318919               5802
# 570   02-03-2568  13210010017  3100602409628               5761
# 2179  02-03-2568  13210010789  3160300318417               5519
# 2214  02-03-2568  12180004906  1103100116124               5485
# 2507  02-03-2568  12170055383  3520800561376               1789
#
#       total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 41                      0                    21963                     91
# 2518                    0                    10364                     91
# 4652                    0                     9550                     91
# 1907                    0                    10221                     91
# 39                      0                    12842                     91
# ...                   ...                      ...                    ...
# 4988                    0                     1392                     91
# 570                     0                     4174                     91
# 2179                    0                     2238                     91
# 2214                    0                      649                     91
# 2507                    0                      403                     91
#
#       overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 41                       4            91                      4  ...
# 2518                     4            91                      4  ...
# 4652                     4            91                      4  ...
# 1907                     4            91                      4  ...
# 39                       4            91                      4  ...
# ...                    ...           ...                    ...  ...
# 4988                     4            91                      4  ...
# 570                      4            91                      4  ...
# 2179                     4            91                      4  ...
# 2214                     4            91                      4  ...
# 2507                     4            91                      4  ...
#
#      product_df1 status_lm old_oa  new_oa reason  product_val  product_df2  \
# 41      RL ML TL    UNSAVE    KOR     KWC    NaN     RL ML TL     RL ML TL
# 2518         TDR    UNSAVE    KWC     MMN    NaN     RL ML TL     RL ML TL
# 4652         TDR    UNSAVE    ACT     UPC    NaN     RL ML TL     RL ML TL
# 1907         TDR    UNSAVE    ACT     GMV    NaN     RL ML TL     RL ML TL
# 39      RL ML TL    UNSAVE    KOR     MGC    NaN     RL ML TL     RL ML TL
# ...          ...       ...    ...     ...    ...          ...          ...
# 4988         TDR    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 570          TDR    UNSAVE    ACT     KWC    NaN     RL ML TL     RL ML TL
# 2179         TDR    UNSAVE    PCN     KWC    NaN     RL ML TL     RL ML TL
# 2214    RL ML TL    UNSAVE    ACT     KWC    NaN     RL ML TL     RL ML TL
# 2507    RL ML TL    UNSAVE    KOR     KWC    NaN     RL ML TL     RL ML TL
#
#                bucket  group          assign_type
# 41    OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2518  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4652  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1907  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 39    OD3-OD4-OD5-OD6      8  save_old_assign_new
# ...               ...    ...                  ...
# 4988  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 570   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2179  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2214  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2507  OD3-OD4-OD5-OD6      8  save_old_assign_new
#
# [254 rows x 90 columns]
# df_n        base_date  customer_no    customer_no  principal_balance  \
# 4838  02-03-2568  14241637695  1570500212116             677337
# 3678  02-03-2568  14231256441  1150600100496             533554
# 1160  02-03-2568  14231306927  1439900403775             532369
# 3465  02-03-2568  14231040514  1249900338169             526941
# 4087  02-03-2568  14231036451  1430700058219             470648
# ...          ...          ...            ...                ...
# 26    02-03-2568  14220060367  1350300156257                999
# 2120  02-03-2568  14220141649  1343000002915                930
# 576   02-03-2568  12170060351  5120100083021                899
# 3207  02-03-2568  14230620129  1329901188640                835
# 4367  02-03-2568  14220105649  1102003086711                535
#
#       total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 4838                    0                    48815                     91
# 3678                    0                    46775                     91
# 1160                    0                    51424                     91
# 3465                    0                    48290                     91
# 4087                    0                    44563                     91
# ...                   ...                      ...                    ...
# 26                      0                      363                     91
# 2120                    0                      973                     91
# 576                     0                      354                     91
# 3207                    0                      928                     91
# 4367                    0                      535                     91
#
#       overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 4838                     4            91                      4  ...
# 3678                     4            91                      4  ...
# 1160                     4            91                      4  ...
# 3465                     4            91                      4  ...
# 4087                     4            91                      4  ...
# ...                    ...           ...                    ...  ...
# 26                       4            91                      4  ...
# 2120                     4            91                      4  ...
# 576                      4            91                      4  ...
# 3207                     4            91                      4  ...
# 4367                     4            91                      4  ...
#
#      product_df1 status_lm    old_oa  new_oa reason  product_val  product_df2  \
# 4838         C4C    UNSAVE       DHA     DHA    NaN          C4C          C4C
# 3678         C4C    UNSAVE       PCN     PCN    NaN          C4C          C4C
# 1160         C4C    UNSAVE       PCN     DHA    NaN          C4C          C4C
# 3465         C4C    UNSAVE       PCN     PCN    NaN          C4C          C4C
# 4087         C4C    UNSAVE       PCN     DHA    NaN          C4C          C4C
# ...          ...       ...       ...     ...    ...          ...          ...
# 26      RL ML TL    UNSAVE  In-House     KWC    NaN     RL ML TL     RL ML TL
# 2120    RL ML TL    UNSAVE       KOR     KWC    NaN     RL ML TL     RL ML TL
# 576     RL ML TL    UNSAVE       ACT     KWC    NaN     RL ML TL     RL ML TL
# 3207    RL ML TL    UNSAVE       KOR     KWC    NaN     RL ML TL     RL ML TL
# 4367    RL ML TL    UNSAVE       ACT     KWC    NaN     RL ML TL     RL ML TL
#
#                                 bucket  group          assign_type
# 4838  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3678  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 1160  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3465  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4087  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# ...                                ...    ...                  ...
# 26                     OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2120                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 576                    OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3207                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4367                   OD3-OD4-OD5-OD6      8  save_old_assign_new
#
# [1096 rows x 90 columns]
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\Sireetron\AppData\Local\Temp\ipykernel_55784\1720306361.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ar_df['assigned'] = np.random.choice(oa['oa'], size=size, p=oa['%assign'])
# C:\Users\Sireetron\AppData\Local\Temp\ipykernel_55784\1720306361.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ar_df['assigned'] = np.random.choice(oa['oa'], size=size, p=oa['%assign'])
# df_y        base_date  customer_no    customer_no  principal_balance  \
# 680   02-03-2568  12160023110  3100902824566             433667
# 1293  02-03-2568  12180048581  3529900004078             220807
# 1915  02-03-2568  12180040685  3170100125640             215419
# 913   02-03-2568  12180040353  3150600551079             200550
# 1010  02-03-2568  12180051522  3730600517797             193363
# ...          ...          ...            ...                ...
# 2626  02-03-2568  12180000833  1100500482061               2747
# 3732  02-03-2568  12170015520  1309901300008               2685
# 58    02-03-2568  12170000657  1100400492846               2586
# 215   02-03-2568  12180046167  3410400679591               2356
# 1571  02-03-2568  12200000949  1959800076336               1060
#
#       total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 680                     0                    52058                    152
# 1293                    0                    21001                    152
# 1915                    0                    26871                    152
# 913                     0                    23429                    152
# 1010                    0                    25150                    152
# ...                   ...                      ...                    ...
# 2626                    0                      543                    152
# 3732                    0                      581                    152
# 58                      0                      571                    152
# 215                     0                      547                    152
# 1571                    0                      411                    152
#
#       overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 680                      6           152                      6  ...
# 1293                     6           152                      6  ...
# 1915                     6           152                      6  ...
# 913                      6           152                      6  ...
# 1010                     6           152                      6  ...
# ...                    ...           ...                    ...  ...
# 2626                     6           152                      6  ...
# 3732                     6           152                      6  ...
# 58                       6           152                      6  ...
# 215                      6           152                      6  ...
# 1571                     6           152                      6  ...
#
#      product_df1 status_lm old_oa  new_oa reason  product_val  product_df2  \
# 680     RL ML TL    UNSAVE    MMN     KWC    NaN     RL ML TL     RL ML TL
# 1293         TDR    UNSAVE    MMN     MMN    NaN     RL ML TL     RL ML TL
# 1915    RL ML TL    UNSAVE    MGC     UPC    NaN     RL ML TL     RL ML TL
# 913     RL ML TL    UNSAVE    UPC     GMV    NaN     RL ML TL     RL ML TL
# 1010    RL ML TL    UNSAVE    MGC     MGC    NaN     RL ML TL     RL ML TL
# ...          ...       ...    ...     ...    ...          ...          ...
# 2626    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 3732    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 58      RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 215     RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 1571    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
#
#                bucket  group          assign_type
# 680   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1293  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1915  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 913   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1010  OD3-OD4-OD5-OD6      8  save_old_assign_new
# ...               ...    ...                  ...
# 2626  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3732  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 58    OD3-OD4-OD5-OD6      8  save_old_assign_new
# 215   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1571  OD3-OD4-OD5-OD6      8  save_old_assign_new
#
# [231 rows x 90 columns]
# df_n        base_date  customer_no    customer_no  principal_balance  \
# 1604  02-03-2568  12210001500  3130200523108             730781
# 1652  02-03-2568  14231166417  3101900146367             513380
# 241   02-03-2568  12210001309  3101200393965             407958
# 2591  02-03-2568  14231356102  1331200037753             401496
# 4265  02-03-2568  14231041217  1529900509441             391401
# ...          ...          ...            ...                ...
# 4942  02-03-2568  14220067388  1840700073320               1754
# 2816  02-03-2568  14220093803  3440100579893               1568
# 3760  02-03-2568  14220090877  1310100182602               1485
# 4232  02-03-2568  14230442159  1579900987644               1230
# 3484  02-03-2568  14220088597  1100700973432                921
#
#       total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 1604                    0                    77512                    152
# 1652                    0                    67134                    152
# 241                     0                    50316                    152
# 2591                    0                    54404                    152
# 4265                    0                    52952                    152
# ...                   ...                      ...                    ...
# 4942                    0                     1843                    152
# 2816                    0                     1709                    152
# 3760                    0                     1564                    152
# 4232                    0                     1388                    152
# 3484                    0                     1060                    152
#
#       overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 1604                     6           152                      6  ...
# 1652                     6           152                      6  ...
# 241                      6           152                      6  ...
# 2591                     6           152                      6  ...
# 4265                     6           152                      6  ...
# ...                    ...           ...                    ...  ...
# 4942                     6           152                      6  ...
# 2816                     6           152                      6  ...
# 3760                     6           152                      6  ...
# 4232                     6           152                      6  ...
# 3484                     6           152                      6  ...
#
#      product_df1 status_lm old_oa  new_oa reason  product_val  product_df2  \
# 1604    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 1652         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# 241     RL ML TL    UNSAVE    MGC     MMN    NaN     RL ML TL     RL ML TL
# 2591         C4C    UNSAVE    DHA     PCN    NaN          C4C          C4C
# 4265         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# ...          ...       ...    ...     ...    ...          ...          ...
# 4942    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 2816    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 3760    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 4232    RL ML TL    UNSAVE    MMN     KWC    NaN     RL ML TL     RL ML TL
# 3484    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
#
#                                 bucket  group          assign_type
# 1604                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1652  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 241                    OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2591  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4265  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# ...                                ...    ...                  ...
# 4942                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2816                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3760                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4232                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3484                   OD3-OD4-OD5-OD6      8  save_old_assign_new
#
# [933 rows x 90 columns]
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\Sireetron\AppData\Local\Temp\ipykernel_55784\1720306361.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ar_df['assigned'] = np.random.choice(oa['oa'], size=size, p=oa['%assign'])
# C:\Users\Sireetron\AppData\Local\Temp\ipykernel_55784\1720306361.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ar_df['assigned'] = np.random.choice(oa['oa'], size=size, p=oa['%assign'])
# df_y        base_date  customer_no    customer_no  principal_balance  \
# 1403  02-03-2568  12210001945  3600100283887             260736
# 1107  02-03-2568  14220051247  3101401256892             260380
# 1710  02-03-2568  14220089352  3900500195559             142184
# 2200  02-03-2568  14220101648  2330500029753             126585
# 4494  02-03-2568  12180050990  3710500979357             121438
# 597   02-03-2568  14220015200  3100903538001              98485
# 3104  02-03-2568  12180044064  3320700354613              84897
# 3255  02-03-2568  14220086148  3301000491198              84461
# 1945  02-03-2568  12160023411  3101400644538              78416
# 3179  02-03-2568  12160025611  3210200218142              78189
# 2353  02-03-2568  12170060631  5301500006821              75934
# 4383  02-03-2568  12170057035  3650400182164              68787
# 3870  02-03-2568  12160009748  1341500016778              62951
# 398   02-03-2568  12180037920  3101701184927              61398
# 1205  02-03-2568  12210002199  4130700002351              60849
# 2373  02-03-2568  12160011746  1410100105704              58268
# 3905  02-03-2568  12160024887  3170400039412              57435
# 2060  02-03-2568  14220059729  3141400218172              51088
# 1336  02-03-2568  12170018622  1330700120381              48276
# 1618  02-03-2568  12160031533  3640400296984              47795
# 4728  02-03-2568  12180031852  1779800052129              44807
# 4532  02-03-2568  14220060128  1729900300183              44077
# 991   02-03-2568  14220060662  3101701262642              42091
# 611   02-03-2568  12170031356  1539900150515              39776
# 1809  02-03-2568  12170047085  3160400483614              37506
# 4571  02-03-2568  14230225362  3730600802688              35841
# 3901  02-03-2568  12170020821  1349900025976              32423
# 520   02-03-2568  12170038121  1759900114533              31335
# 4709  02-03-2568  14220045683  1769900030941              27467
# 2247  02-03-2568  14220124898  1340700202141              26360
# 4348  02-03-2568  14220128236  1610100111532              26048
# 4099  02-03-2568  14220060254  1430900236137              23459
# 252   02-03-2568  14220087274  5101499039085              22485
# 4859  02-03-2568  12170059614  3900200408328              18792
# 4052  02-03-2568  12180021418  1419900646163              15692
# 4719  02-03-2568  12180030302  1709900658843              15169
# 3783  02-03-2568  14230869120  5310400080867              14184
# 2249  02-03-2568  13200000310  1199900315330               5392
# 4048  02-03-2568  12170052869  3410101629843               5216
# 1444  02-03-2568  12180023892  1460700166861               4840
#
#       total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 1403                    0                    30404                    182
# 1107                    0                    31651                    182
# 1710                    0                    17313                    182
# 2200                    0                    14880                    182
# 4494                    0                    13174                    182
# 597                     0                    13552                    182
# 3104                    0                    10740                    182
# 3255                    0                    11824                    182
# 1945                    0                     9633                    182
# 3179                    0                     9558                    182
# 2353                    0                    17539                    182
# 4383                    0                     8580                    182
# 3870                    0                     8200                    182
# 398                     0                     8651                    182
# 1205                    0                     7590                    182
# 2373                    0                     7306                    182
# 3905                    0                     7158                    182
# 2060                    0                     6916                    182
# 1336                    0                     6021                    182
# 1618                    0                     7227                    182
# 4728                    0                     7117                    182
# 4532                    0                     5793                    182
# 991                     0                     9610                    182
# 611                     0                     5065                    182
# 1809                    0                     8830                    182
# 4571                    0                     4676                    182
# 3901                    0                     4224                    182
# 520                     0                     4259                    182
# 4709                    0                     3639                    182
# 2247                    0                     3556                    182
# 4348                    0                     3448                    182
# 4099                    0                     5848                    182
# 252                     0                     2998                    182
# 4859                    0                     2829                    182
# 4052                    0                     2169                    182
# 4719                    0                     3199                    182
# 3783                    0                     1766                    182
# 2249                    0                     6010                    182
# 4048                    0                     5930                    182
# 1444                    0                     5017                    182
#
#       overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 1403                     7           182                      7  ...
# 1107                     7           182                      7  ...
# 1710                     7           182                      7  ...
# 2200                     7           182                      7  ...
# 4494                     7           182                      7  ...
# 597                      7           182                      7  ...
# 3104                     7           182                      7  ...
# 3255                     7           182                      7  ...
# 1945                     7           182                      7  ...
# 3179                     7           182                      7  ...
# 2353                     7           182                      7  ...
# 4383                     7           182                      7  ...
# 3870                     7           182                      7  ...
# 398                      7           182                      7  ...
# 1205                     7           182                      7  ...
# 2373                     7           182                      7  ...
# 3905                     7           182                      7  ...
# 2060                     7           182                      7  ...
# 1336                     7           182                      7  ...
# 1618                     7           182                      7  ...
# 4728                     7           182                      7  ...
# 4532                     7           182                      7  ...
# 991                      7           182                      7  ...
# 611                      7           182                      7  ...
# 1809                     7           182                      7  ...
# 4571                     7           182                      7  ...
# 3901                     7           182                      7  ...
# 520                      7           182                      7  ...
# 4709                     7           182                      7  ...
# 2247                     7           182                      7  ...
# 4348                     7           182                      7  ...
# 4099                     7           182                      7  ...
# 252                      7           182                      7  ...
# 4859                     7           182                      7  ...
# 4052                     7           182                      7  ...
# 4719                     7           182                      7  ...
# 3783                     7           182                      7  ...
# 2249                     7           182                      7  ...
# 4048                     7           182                      7  ...
# 1444                     7           182                      7  ...
#
#      product_df1 status_lm old_oa  new_oa reason  product_val  product_df2  \
# 1403         TDR    UNSAVE    MGC     KWC    NaN     RL ML TL     RL ML TL
# 1107         TDR    UNSAVE    GMV     MMN    NaN     RL ML TL     RL ML TL
# 1710         TDR    UNSAVE    MGC     UPC    NaN     RL ML TL     RL ML TL
# 2200         TDR    UNSAVE    UPC     GMV    NaN     RL ML TL     RL ML TL
# 4494         TDR    UNSAVE    GMV     MGC    NaN     RL ML TL     RL ML TL
# 597          TDR    UNSAVE    GMV     KWC    NaN     RL ML TL     RL ML TL
# 3104         TDR    UNSAVE    UPC     MMN    NaN     RL ML TL     RL ML TL
# 3255         TDR    UNSAVE    KWC     UPC    NaN     RL ML TL     RL ML TL
# 1945         TDR    UNSAVE    MGC     GMV    NaN     RL ML TL     RL ML TL
# 3179         TDR    UNSAVE    GMV     MGC    NaN     RL ML TL     RL ML TL
# 2353         TDR    UNSAVE    UPC     KWC    NaN     RL ML TL     RL ML TL
# 4383         TDR    UNSAVE    UPC     MMN    NaN     RL ML TL     RL ML TL
# 3870         TDR    UNSAVE    MGC     UPC    NaN     RL ML TL     RL ML TL
# 398          TDR    UNSAVE    UPC     GMV    NaN     RL ML TL     RL ML TL
# 1205         TDR    UNSAVE    KWC     MGC    NaN     RL ML TL     RL ML TL
# 2373         TDR    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 3905         TDR    UNSAVE    MGC     MMN    NaN     RL ML TL     RL ML TL
# 2060         TDR    UNSAVE    UPC     UPC    NaN     RL ML TL     RL ML TL
# 1336         TDR    UNSAVE    MMN     GMV    NaN     RL ML TL     RL ML TL
# 1618         TDR    UNSAVE    MGC     MGC    NaN     RL ML TL     RL ML TL
# 4728         TDR    UNSAVE    UPC     KWC    NaN     RL ML TL     RL ML TL
# 4532         TDR    UNSAVE    UPC     MMN    NaN     RL ML TL     RL ML TL
# 991          TDR    UNSAVE    UPC     UPC    NaN     RL ML TL     RL ML TL
# 611          TDR    UNSAVE    MGC     GMV    NaN     RL ML TL     RL ML TL
# 1809         TDR    UNSAVE    UPC     MGC    NaN     RL ML TL     RL ML TL
# 4571         TDR    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 3901         TDR    UNSAVE    UPC     MMN    NaN     RL ML TL     RL ML TL
# 520          TDR    UNSAVE    MGC     UPC    NaN     RL ML TL     RL ML TL
# 4709         TDR    UNSAVE    KWC     GMV    NaN     RL ML TL     RL ML TL
# 2247         TDR    UNSAVE    MGC     KWC    NaN     RL ML TL     RL ML TL
# 4348         TDR    UNSAVE    GMV     MMN    NaN     RL ML TL     RL ML TL
# 4099         TDR    UNSAVE    UPC     UPC    NaN     RL ML TL     RL ML TL
# 252          TDR    UNSAVE    GMV     GMV    NaN     RL ML TL     RL ML TL
# 4859         TDR    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 4052         TDR    UNSAVE    UPC     MMN    NaN     RL ML TL     RL ML TL
# 4719         TDR    UNSAVE    MMN     UPC    NaN     RL ML TL     RL ML TL
# 3783         TDR    UNSAVE    MGC     KWC    NaN     RL ML TL     RL ML TL
# 2249    RL ML TL    UNSAVE    KWC     MMN    NaN     RL ML TL     RL ML TL
# 4048         TDR    UNSAVE    MGC     KWC    NaN     RL ML TL     RL ML TL
# 1444         TDR    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
#
#                bucket  group          assign_type
# 1403  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1107  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1710  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2200  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4494  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 597   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3104  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3255  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1945  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3179  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2353  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4383  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3870  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 398   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1205  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2373  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3905  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2060  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1336  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1618  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4728  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4532  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 991   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 611   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1809  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4571  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3901  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 520   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4709  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2247  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4348  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4099  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 252   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4859  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4052  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4719  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3783  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2249  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4048  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1444  OD3-OD4-OD5-OD6      8  save_old_assign_new
#
# [40 rows x 90 columns]
# df_n        base_date  customer_no    customer_no  principal_balance  \
# 3867  02-03-2568  14231175302  5340900059441             434457
# 3926  02-03-2568  14231576844  1350100209772             401661
# 3847  02-03-2568  14230232338  3440100320296             386479
# 3995  02-03-2568  14220090414  3400100937692             337919
# 3828  02-03-2568  14230796185  3460200051009             306857
# ...          ...          ...            ...                ...
# 3317  02-03-2568  14220027329  1101501015076               1858
# 3864  02-03-2568  14230490579  1349700117117               1217
# 1497  02-03-2568  14220075144  3141000115121               1090
# 4132  02-03-2568  14230337255  1459900365032               1006
# 4636  02-03-2568  14230381403  1749900743981                857
#
#       total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 3867                    0                    65734                    182
# 3926                    0                    62230                    182
# 3847                    0                    90657                    182
# 3995                    0                    76346                    182
# 3828                    0                    47923                    182
# ...                   ...                      ...                    ...
# 3317                    0                     2007                    182
# 3864                    0                     1392                    182
# 1497                    0                     1244                    182
# 4132                    0                     1140                    182
# 4636                    0                     1000                    182
#
#       overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 3867                     7           182                      7  ...
# 3926                     7           182                      7  ...
# 3847                     7           182                      7  ...
# 3995                     7           182                      7  ...
# 3828                     7           182                      7  ...
# ...                    ...           ...                    ...  ...
# 3317                     7           182                      7  ...
# 3864                     7           182                      7  ...
# 1497                     7           182                      7  ...
# 4132                     7           182                      7  ...
# 4636                     7           182                      7  ...
#
#      product_df1 status_lm old_oa  new_oa reason  product_val  product_df2  \
# 3867         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# 3926         C4C    UNSAVE    PCN     PCN    NaN          C4C          C4C
# 3847         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# 3995         C4C    UNSAVE    PCN     PCN    NaN          C4C          C4C
# 3828         C4C    UNSAVE    PCN     DHA    NaN          C4C          C4C
# ...          ...       ...    ...     ...    ...          ...          ...
# 3317    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 3864    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 1497    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 4132    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 4636    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
#
#                                 bucket  group          assign_type
# 3867  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3926  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3847  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3995  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3828  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# ...                                ...    ...                  ...
# 3317                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3864                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1497                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4132                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4636                   OD3-OD4-OD5-OD6      8  save_old_assign_new
#
# [113 rows x 90 columns]
# df_y        base_date  customer_no    customer_no  principal_balance  \
# 1300  02-03-2568  12180039702  3129900316448             513056
# 612   02-03-2568  12160030430  3520300034342             280544
# 1528  02-03-2568  12180039991  3140500045244             216507
# 2440  02-03-2568  12210000948  1640900051542             207030
# 4660  02-03-2568  11150020835  3919900045676             190865
# ...          ...          ...            ...                ...
# 1316  02-03-2568  12170051950  3350800203153               3761
# 3547  02-03-2568  12180011043  1250200241822               3537
# 2255  02-03-2568  12180049521  3610600231436               3244
# 3806  02-03-2568  12170016038  1310700201004               2944
# 2735  02-03-2568  12180012838  1309900721476               2113
#
#       total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 1300                    0                    42886                    121
# 612                     0                    29306                    121
# 1528                    0                    18470                    121
# 2440                    0                    19997                    121
# 4660                    0                    16535                    121
# ...                   ...                      ...                    ...
# 1316                    0                      614                    121
# 3547                    0                      593                    121
# 2255                    0                      575                    121
# 3806                    0                      549                    121
# 2735                    0                      480                    121
#
#       overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 1300                     5           121                      5  ...
# 612                      5           121                      5  ...
# 1528                     5           121                      5  ...
# 2440                     5           121                      5  ...
# 4660                     5           121                      5  ...
# ...                    ...           ...                    ...  ...
# 1316                     5           121                      5  ...
# 3547                     5           121                      5  ...
# 2255                     5           121                      5  ...
# 3806                     5           121                      5  ...
# 2735                     5           121                      5  ...
#
#      product_df1 status_lm old_oa  new_oa reason  product_val  product_df2  \
# 1300         TDR    UNSAVE    MGC     KWC    NaN     RL ML TL     RL ML TL
# 612     RL ML TL    UNSAVE    MGC     MMN    NaN     RL ML TL     RL ML TL
# 1528         TDR    UNSAVE    MMN     UPC    NaN     RL ML TL     RL ML TL
# 2440    RL ML TL    UNSAVE    MGC     GMV    NaN     RL ML TL     RL ML TL
# 4660         TDR    UNSAVE    MMN     MGC    NaN     RL ML TL     RL ML TL
# ...          ...       ...    ...     ...    ...          ...          ...
# 1316    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 3547    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 2255    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 3806    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 2735    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
#
#                bucket  group          assign_type
# 1300  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 612   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 1528  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2440  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4660  OD3-OD4-OD5-OD6      8  save_old_assign_new
# ...               ...    ...                  ...
# 1316  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3547  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2255  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 3806  OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2735  OD3-OD4-OD5-OD6      8  save_old_assign_new
#
# [247 rows x 90 columns]
# df_n        base_date  customer_no    customer_no  principal_balance  \
# 504   02-03-2568  12210002263  5659900001121             666770
# 4104  02-03-2568  14231235238  3430501179454             527137
# 4716  02-03-2568  14231375659  1209700547759             404460
# 795   02-03-2568  12210001870  3480800002211             381987
# 4308  02-03-2568  14230883596  3570700546511             373856
# ...          ...          ...            ...                ...
# 1148  02-03-2568  14220096562  1639800227141               1649
# 2853  02-03-2568  14230770488  1410601384622               1445
# 2535  02-03-2568  14220095542  3200200360526               1357
# 2096  02-03-2568  14230391247  1329400007022               1226
# 353   02-03-2568  14220074961  1720500117448               1180
#
#       total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 504                     0                    60518                    121
# 4104                    0                    58465                    121
# 4716                    0                    44386                    121
# 795                     0                    39948                    121
# 4308                    0                    43330                    121
# ...                   ...                      ...                    ...
# 1148                    0                     1699                    121
# 2853                    0                     1589                    121
# 2535                    0                     1477                    121
# 2096                    0                     1283                    121
# 353                     0                     1231                    121
#
#       overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 504                      5           121                      5  ...
# 4104                     5           121                      5  ...
# 4716                     5           121                      5  ...
# 795                      5           121                      5  ...
# 4308                     5           121                      5  ...
# ...                    ...           ...                    ...  ...
# 1148                     5           121                      5  ...
# 2853                     5           121                      5  ...
# 2535                     5           121                      5  ...
# 2096                     5           121                      5  ...
# 353                      5           121                      5  ...
#
#      product_df1 status_lm old_oa  new_oa reason  product_val  product_df2  \
# 504     RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 4104         C4C    UNSAVE    PCN     DHA    NaN          C4C          C4C
# 4716         C4C    UNSAVE    PCN     PCN    NaN          C4C          C4C
# 795     RL ML TL    UNSAVE    GMV     MMN    NaN     RL ML TL     RL ML TL
# 4308         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# ...          ...       ...    ...     ...    ...          ...          ...
# 1148    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 2853    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 2535    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 2096    RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
# 353     RL ML TL    UNSAVE    KWC     KWC    NaN     RL ML TL     RL ML TL
#
#                                 bucket  group          assign_type
# 504                    OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4104  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4716  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 795                    OD3-OD4-OD5-OD6      8  save_old_assign_new
# 4308  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# ...                                ...    ...                  ...
# 1148                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2853                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2535                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 2096                   OD3-OD4-OD5-OD6      8  save_old_assign_new
# 353                    OD3-OD4-OD5-OD6      8  save_old_assign_new
#
# [1124 rows x 90 columns]
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\Sireetron\AppData\Local\Temp\ipykernel_55784\1720306361.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# 3085  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 5006  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 760   XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4238  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 5015  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3949  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4362  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 2988  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4825  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4611  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 1548  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3451  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 5007  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4296  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4814  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 5058  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3726  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 414   XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 1273  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 5025  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4284  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4195  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 2086  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 1109  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4248  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 314   XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3557  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 1266  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4032  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 1274  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4212  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4386  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4184  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 5043  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4698  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4578  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 730   XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
#
# [39 rows x 90 columns]
# df_y Empty DataFrame
# Columns: [base_date, customer_no, customer_no, principal_balance, total_unclaimed_amt, repayment_target_amount, overdue_days(morning), overdue_cnt(morning), overdue_days, num_of_overdue_months, overdue_months_division_code, corp_info, sales_product_code, contract_no, customer_name, customer_no, mobile_no, address(home), post_code, phone_no(home), address(office), post_code1, biz_phone_no, address_(place_of_residence), post_code, phone_no, delivery_address, post_code2, delivery_phone_no, customer_relationship, related_person, phone_no_1, customer_relationship1, related_person1, phone_no_2, branch_code, outstanding_balance, loan_date, installment_count, product_name, last_money_received_date, last_payment_amt, loan_amt, principal, monthly_payment_amt, _first_settlement_date, last_payment_date, billing_interest_amt, billing_credit_usage_amount, overdue_start_date, overdue_int, overdue_credit_usage_amount, collection_fee, overdue_sum_amt, overdue_months_division_code1, dob, marital_status, phone_no_3, company_name, company_extension_no, headquarter_phone_no, headquarter_extension_no, monthly_income, email_address, next_payment_due_date, next_payment_amt, payment_date, total_count, number_of_deposit_on_1st_of_month, number_of_deposit_on/before_5th_of_month, number_of_deposit_before_24th_of_month, number_of_deposit_before_25th_of_month, number_of_deposit_at_the_end_of_month, last_payment_amt1, biz_industry_code, occupation, sales_product_code1, waived_processing_amt(xday), extend_term_changed_count, ever, product_df1, status_lm, old_oa, new_oa, reason, product_val, product_df2, bucket, group, assign_type]
# Index: []
#
# [0 rows x 90 columns]
# df_n        base_date  customer_no    customer_no  principal_balance  \
# 3618  02-03-2568  14230302732  3309901326160             667035
# 3461  02-03-2568  14230223144  1159900243916             526085
# 1951  02-03-2568  14231145787  3101300067628             505894
# 4271  02-03-2568  14230558262  1509900980011             475331
# 1755  02-03-2568  14231444031  3100904987543             473981
# 4301  02-03-2568  14230983333  3570300381841             452951
# 3917  02-03-2568  14231311323  2110400037985             424472
# 4114  02-03-2568  14231202194  3440800498195             345765
# 3961  02-03-2568  14231240637  1360700044316             345631
# 4211  02-03-2568  14230484966  5501001207072             336930
# 4830  02-03-2568  14220057727  1810400099013             308321
# 4281  02-03-2568  14230966616  1549900506883             273744
# 319   02-03-2568  14231039332  1102002619147             245955
# 3776  02-03-2568  14230273321  3311000709207             244382
# 4205  02-03-2568  11160003496  1101400900490             242474
# 3817  02-03-2568  14231407615  3310200178549             237499
# 4054  02-03-2568  14231313356  3410100151575             234392
# 3979  02-03-2568  14230663455  1411400153411             226263
# 4884  02-03-2568  14230719872  1800700118081             218063
# 5020  02-03-2568  14231038175  1909900219503             217431
# 4828  02-03-2568  14220057741  3810400123638             216482
# 5037  02-03-2568  14231414409  1909800052844             198584
# 4966  02-03-2568  14231009844  3841000086507             191509
# 4751  02-03-2568  14230315518  3801200264875             169442
# 3593  02-03-2568  14220031035  1319800098785             169099
# 4808  02-03-2568  14230333294  3801000211689             153505
# 2761  02-03-2568  14220090251  1200100464226             137034
# 3913  02-03-2568  14231393432  1340700253284             134027
# 1168  02-03-2568  14230625329  1640600149644             131348
#
#       total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 3618                    0                    45950                     60
# 3461                    0                    37339                     60
# 1951                    0                    42312                     60
# 4271                    0                    34196                     60
# 1755                    0                    34430                     60
# 4301                    0                    35383                     60
# 3917                    0                    29117                     60
# 4114                    0                    18270                     60
# 3961                    0                    21639                     60
# 4211                    0                    24593                     60
# 4830                    0                    36779                     60
# 4281                    0                    20968                     60
# 319                     0                    21425                     60
# 3776                    0                    24351                     60
# 4205                    0                    24423                     60
# 3817                    0                    18020                     60
# 4054                    0                    22596                     60
# 3979                    0                    22923                     60
# 4884                    0                    26000                     60
# 5020                    0                    20637                     60
# 4828                    0                    25874                     60
# 5037                    0                    15112                     60
# 4966                    0                    19029                     60
# 4751                    0                    17960                     60
# 3593                    0                    21018                     60
# 4808                    0                    11444                     60
# 2761                    0                    15718                     60
# 3913                    0                    10408                     60
# 1168                    0                    13735                     60
#
#       overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 3618                     3            60                      3  ...
# 3461                     3            60                      3  ...
# 1951                     3            60                      3  ...
# 4271                     3            60                      3  ...
# 1755                     3            60                      3  ...
# 4301                     3            60                      3  ...
# 3917                     3            60                      3  ...
# 4114                     3            60                      3  ...
# 3961                     3            60                      3  ...
# 4211                     3            60                      3  ...
# 4830                     3            60                      3  ...
# 4281                     3            60                      3  ...
# 319                      3            60                      3  ...
# 3776                     3            60                      3  ...
# 4205                     3            60                      3  ...
# 3817                     3            60                      3  ...
# 4054                     3            60                      3  ...
# 3979                     3            60                      3  ...
# 4884                     3            60                      3  ...
# 5020                     3            60                      3  ...
# 4828                     3            60                      3  ...
# 5037                     3            60                      3  ...
# 4966                     3            60                      3  ...
# 4751                     3            60                      3  ...
# 3593                     3            60                      3  ...
# 4808                     3            60                      3  ...
# 2761                     3            60                      3  ...
# 3913                     3            60                      3  ...
# 1168                     3            60                      3  ...
#
#      product_df1 status_lm old_oa  new_oa reason  product_val  product_df2  \
# 3618         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# 3461         C4C    UNSAVE    PCN     PCN    NaN          C4C          C4C
# 1951         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# 4271         C4C    UNSAVE    DHA     PCN    NaN          C4C          C4C
# 1755         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# 4301         C4C    UNSAVE    PCN     PCN    NaN          C4C          C4C
# 3917         C4C    UNSAVE    PCN     DHA    NaN          C4C          C4C
# 4114         C4C    UNSAVE    PCN     PCN    NaN          C4C          C4C
# 3961         C4C    UNSAVE    PCN     DHA    NaN          C4C          C4C
# 4211         C4C    UNSAVE    DHA     PCN    NaN          C4C          C4C
# 4830         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# 4281         C4C    UNSAVE    PCN     PCN    NaN          C4C          C4C
# 319          C4C    UNSAVE    PCN     DHA    NaN          C4C          C4C
# 3776         C4C    UNSAVE    DHA     PCN    NaN          C4C          C4C
# 4205         C4C    UNSAVE    PCN     DHA    NaN          C4C          C4C
# 3817         C4C    UNSAVE    DHA     PCN    NaN          C4C          C4C
# 4054         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# 3979         C4C    UNSAVE    DHA     PCN    NaN          C4C          C4C
# 4884         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# 5020         C4C    UNSAVE    PCN     PCN    NaN          C4C          C4C
# 4828         C4C    UNSAVE    PCN     DHA    NaN          C4C          C4C
# 5037         C4C    UNSAVE    DHA     PCN    NaN          C4C          C4C
# 4966         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# 4751         C4C    UNSAVE    DHA     PCN    NaN          C4C          C4C
# 3593         C4C    UNSAVE    PCN     DHA    NaN          C4C          C4C
# 4808         C4C    UNSAVE    PCN     DHA    NaN          C4C          C4C
# 2761         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
# 3913         C4C    UNSAVE    PCN     DHA    NaN          C4C          C4C
# 1168         C4C    UNSAVE    DHA     DHA    NaN          C4C          C4C
#
#                                 bucket  group          assign_type
# 3618  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3461  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 1951  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4271  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 1755  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4301  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3917  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4114  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3961  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4211  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4830  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4281  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 319   XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3776  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4205  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3817  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4054  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3979  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4884  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 5020  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4828  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 5037  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4966  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4751  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3593  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 4808  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 2761  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 3913  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
# 1168  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL      3  save_old_assign_new
#
# [29 rows x 90 columns]
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %% [markdown]
# ----------------------------

# %%
save_old_assign_new = ar_merge[ar_merge['assign_type'] == 'save_old_assign_new'].reset_index(drop=True)
save_old  = save_old_assign_new.loc[ (save_old_assign_new['status_lm'] == 'SAVE')]
save_old['assigned'] = save_old['old_oa']
assign_new =  save_old_assign_new.loc[ ~(save_old_assign_new['status_lm'] == 'SAVE')]

# %%
assign_new
# Out:
#       base_date  customer_no    customer_no  principal_balance  \
# 0      02-04-68  14220001105  1189900322662               1329
# 1      02-04-68  14220134943  3100202287312               1246
# 2      02-04-68  14220154491  3400600541658                539
# 3      02-04-68  14220137826  1800600148549                547
# 4      02-04-68  14220144883  3102002143718               1560
# ...         ...          ...            ...                ...
# 24789  02-04-68  14231185266  1419901887938              10467
# 24790  02-04-68  14242910960  1849901381763               5981
# 24791  02-04-68  14242387135  1199600053615               5981
# 24792  02-04-68  14230817713  3841500429420              14952
# 24793  02-04-68  14242878881  3440800956053               5981
#
#        total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 0                      NaN                     1446                     91
# 1                      NaN                     1355                     91
# 2                      NaN                      586                     91
# 3                      NaN                      595                     91
# 4                      NaN                     1698                     91
# ...                    ...                      ...                    ...
# 24789                  NaN                     5537                    183
# 24790                  NaN                     4623                    183
# 24791                  NaN                     4623                    183
# 24792                  NaN                     7746                    183
# 24793                  NaN                     4623                    183
#
#        overdue_cnt(morning)  overdue_days  num_of_overdue_months  ...  \
# 0                         4            91                      4  ...
# 1                         4            91                      4  ...
# 2                         4            91                      4  ...
# 3                         4            91                      4  ...
# 4                         4            91                      4  ...
# ...                     ...           ...                    ...  ...
# 24789                     7           183                      7  ...
# 24790                     7           183                      7  ...
# 24791                     7           183                      7  ...
# 24792                     7           183                      7  ...
# 24793                     7           183                      7  ...
#
#       product_df1 status_lm    old_oa  new_oa c_score  product_val  \
# 0             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 1             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 2             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 3             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# 4             SF+    UNSAVE  In-House     NaN     NaN       SFLoan
# ...           ...       ...       ...     ...     ...          ...
# 24789         SF+    UNSAVE       LBR     NaN     NaN       SFLoan
# 24790         SF+    UNSAVE       ASJ     NaN     NaN       SFLoan
# 24791         SF+    UNSAVE       WSP     NaN     NaN       SFLoan
# 24792         SF+    UNSAVE       MGC     NaN     NaN       SFLoan
# 24793         SF+    UNSAVE      THAS     NaN     NaN       SFLoan
#
#        product_df2           bucket  group          assign_type
# 0           SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 1           SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 2           SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 3           SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 4           SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# ...            ...              ...    ...                  ...
# 24789       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 24790       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 24791       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 24792       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
# 24793       SFLoan  OD3-OD4-OD5-OD6      6  save_old_assign_new
#
# [24794 rows x 90 columns]

# %%
assign_new= assign_to_oa(assign_new)

# %%
assign_new['contract_no'] = assign_new['contract_no'].astype(str)

# %%
assign_new.to_excel('./output/sf_assigned.xlsx')

# %%
save_old_assign_new = pd.concat([save_old.reset_index(drop=True), 
           assign_new.reset_index(drop=True)],  ignore_index=True)

# %%
save_old_assign_new[['contract_no']]
# Out:
#            contract_no
# 0     5002764061000737
# 1     5002764031000666
# 2     7240750103345040
# 3     5002761051087535
# 4     5002764031001891
# ...                ...
# 5092  7221040100014999
# 5093  7221040100011623
# 5094  7230440100436485
# 5095  5000160121044030
# 5096  7221040100008827
#
# [5097 rows x 1 columns]

# %%
save_old_assign_new['contract_no'] = save_old_assign_new['contract_no'].astype(str)

# %%
save_old_assign_new.to_excel('./output/npl_assign.xlsx')

# %%
assign_all = ar_merge[ar_merge['assign_type'] == 'assign_all'].reset_index(drop=True)
assign_all= assign_to_oa(assign_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 assign_all = ar_merge[ar_merge['assign_type'] == 'assign_all'].reset_index(drop=True)
# ----> 2 assign_all= assign_to_oa(assign_all)
#
# Cell In[21], line 40, in assign_to_oa(df_toassign)
#      37     combined_dfs.append(assigned_df)
#      39 # Concatenate all the combined dataframes into one final dataframe
# ---> 40 final_df = pd.concat(combined_dfs, ignore_index=True)
#      42 # Optionally, assign the final concatenated dataframe to a dynamic variable
#      43 globals()['df_assign_all'] = final_df
#
# File c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
ar_merge
# Out:
#        base_date  customer_no    customer_no  principal_balance  \
# 0     02-04-2568  14230278256  3650800836587              49107
# 2     02-04-2568  12180007377  1149900044735              22749
# 4     02-04-2568  14231018853  1200101709486              20035
# 6     02-04-2568  12170022644  1400100066555              18695
# 8     02-04-2568  14220105934  1340500155971              14594
# ...          ...          ...            ...                ...
# 2472  02-04-2568  14220066187  3340300117924               1065
# 2474  02-04-2568  14230979770  3520500266042               1043
# 2476  02-04-2568  14220146031  1119900443001                910
# 2478  02-04-2568  14231170896  3140100332351                642
# 2480  02-04-2568  12180011153  1250500110821                372
#
#       total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 0                       0                     1073                      1
# 2                       0                      569                      1
# 4                       0                      300                      1
# 6                       0                      235                      1
# 8                       0                      349                      1
# ...                   ...                      ...                    ...
# 2472                    0                      300                      1
# 2474                    0                      300                      1
# 2476                    0                      930                      1
# 2478                    0                      672                      1
# 2480                    0                      300                      1
#
#       overdue_cnt(morning)  overdue_days  num_of_overdue_months  ... ever  \
# 0                        1             1                      1  ...    N
# 2                        1             1                      1  ...    Y
# 4                        1             1                      1  ...    N
# 6                        1             1                      1  ...    Y
# 8                        1             1                      1  ...    N
# ...                    ...           ...                    ...  ...  ...
# 2472                     1             1                      1  ...    N
# 2474                     1             1                      1  ...    N
# 2476                     1             1                      1  ...    N
# 2478                     1             1                      1  ...    N
# 2480                     1             1                      1  ...    Y
#
#      product_df1 status_lm  old_oa new_oa  product_val  product_df2  \
# 0       RL ML TL       NEW     NaN    NaN     RL ML TL     RL ML TL
# 2       RL ML TL       NEW     NaN    NaN     RL ML TL     RL ML TL
# 4       RL ML TL       NEW     NaN    NaN     RL ML TL     RL ML TL
# 6       RL ML TL       NEW     NaN    NaN     RL ML TL     RL ML TL
# 8       RL ML TL       NEW     NaN    NaN     RL ML TL     RL ML TL
# ...          ...       ...     ...    ...          ...          ...
# 2472    RL ML TL       NEW     NaN    NaN     RL ML TL     RL ML TL
# 2474    RL ML TL       NEW     NaN    NaN     RL ML TL     RL ML TL
# 2476    RL ML TL       NEW     NaN    NaN     RL ML TL     RL ML TL
# 2478    RL ML TL       NEW     NaN    NaN     RL ML TL     RL ML TL
# 2480    RL ML TL       NEW     NaN    NaN     RL ML TL     RL ML TL
#
#             bucket  group            assign_type
# 0     XDAY-OD1-OD2      7  assign_old_assign_new
# 2     XDAY-OD1-OD2      7  assign_old_assign_new
# 4     XDAY-OD1-OD2      7  assign_old_assign_new
# 6     XDAY-OD1-OD2      7  assign_old_assign_new
# 8     XDAY-OD1-OD2      7  assign_old_assign_new
# ...            ...    ...                    ...
# 2472  XDAY-OD1-OD2      7  assign_old_assign_new
# 2474  XDAY-OD1-OD2      7  assign_old_assign_new
# 2476  XDAY-OD1-OD2      7  assign_old_assign_new
# 2478  XDAY-OD1-OD2      7  assign_old_assign_new
# 2480  XDAY-OD1-OD2      7  assign_old_assign_new
#
# [1241 rows x 89 columns]

# %%
assign_old_assign_new = ar_merge[ar_merge['assign_type'] == 'assign_old_assign_new'].reset_index(drop=True)
assign_old  = assign_old_assign_new.loc[ (assign_old_assign_new['status_lm'] == 'SAVE')]
assign_old
# Out:
# Empty DataFrame
# Columns: [base_date, customer_no, customer_no, principal_balance, total_unclaimed_amt, repayment_target_amount, overdue_days(morning), overdue_cnt(morning), overdue_days, num_of_overdue_months, overdue_months_division_code, corp_info, sales_product_code, contract_no, customer_name, customer_no, mobile_no, address(home), post_code, phone_no(home), address(office), post_code1, biz_phone_no, address_(place_of_residence), post_code, phone_no, delivery_address, post_code2, delivery_phone_no, customer_relationship, related_person, phone_no_1, customer_relationship1, related_person1, phone_no_2, branch_code, outstanding_balance, loan_date, installment_count, product_name, last_money_received_date, last_payment_amt, loan_amt, principal, monthly_payment_amt, _first_settlement_date, last_payment_date, billing_interest_amt, billing_credit_usage_amount, overdue_start_date, overdue_int, overdue_credit_usage_amount, collection_fee, overdue_sum_amt, overdue_months_division_code1, dob, marital_status, phone_no_3, company_name, company_extension_no, headquarter_phone_no, headquarter_extension_no, monthly_income, email_address, next_payment_due_date, next_payment_amt, payment_date, total_count, number_of_deposit_on_1st_of_month, number_of_deposit_on/before_5th_of_month, number_of_deposit_before_24th_of_month, number_of_deposit_before_25th_of_month, number_of_deposit_at_the_end_of_month, last_payment_amt1, biz_industry_code, occupation, sales_product_code1, waived_processing_amt(xday), extend_term_changed_count, ever, product_df1, status_lm, old_oa, new_oa, product_val, product_df2, bucket, group, assign_type]
# Index: []
#
# [0 rows x 89 columns]

# %%
oa_proportion
# Out:
#      product                            bucket %assign        oa  group  \
# 0        H4C                              XDAY    1.00  In-House      1
# 1        H4C                           OD1-OD2    1.00       JMT      2
# 2        C4C  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL    0.60       DHA      3
# 3        C4C  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL    0.40       PCN      3
# 4        SF+                             X-DAY    1.00  In-House      4
# 5        SF+                           OD1-OD2    1.00  In-House      5
# 6        SF+                               NPL    0.20      THAS      6
# 7        SF+                               NPL    0.18       LBR      6
# 8        SF+                               NPL    0.17       ASJ      6
# 9        SF+                               NPL    0.16       WSP      6
# 10       SF+                               NPL    0.15       PCN      6
# 11       SF+                               NPL    0.14       MGC      6
# 12  RL ML TL                      XDAY-OD1-OD2    0.20       PCN      7
# 13  RL ML TL                      XDAY-OD1-OD2    0.19       ACT      7
# 14  RL ML TL                      XDAY-OD1-OD2    0.14  In-House      7
# 15  RL ML TL                      XDAY-OD1-OD2    0.17       DHA      7
# 16  RL ML TL                      XDAY-OD1-OD2    0.12       KOR      7
# 17  RL ML TL                      XDAY-OD1-OD2    0.08       KWC      7
# 18  RL ML TL                      XDAY-OD1-OD2    0.10       MMN      7
# 19  RL ML TL                   OD3-OD4-OD5-OD6    0.32       KWC      8
# 20  RL ML TL                   OD3-OD4-OD5-OD6    0.27       MMN      8
# 21  RL ML TL                   OD3-OD4-OD5-OD6    0.23       GMV      8
# 22  RL ML TL                   OD3-OD4-OD5-OD6    0.18       UPC      8
#
#               assign_type
# 0              assign_all
# 1              assign_all
# 2     save_old_assign_new
# 3     save_old_assign_new
# 4              assign_all
# 5              assign_all
# 6     save_old_assign_new
# 7     save_old_assign_new
# 8     save_old_assign_new
# 9     save_old_assign_new
# 10    save_old_assign_new
# 11    save_old_assign_new
# 12  assign_old_assign_new
# 13  assign_old_assign_new
# 14  assign_old_assign_new
# 15  assign_old_assign_new
# 16  assign_old_assign_new
# 17  assign_old_assign_new
# 18  assign_old_assign_new
# 19    save_old_assign_new
# 20    save_old_assign_new
# 21    save_old_assign_new
# 22    save_old_assign_new

# %%
assign_old= assign_to_oa(assign_old)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 assign_old= assign_to_oa(assign_old)
#
# Cell In[148], line 40, in assign_to_oa(df_toassign)
#      37     combined_dfs.append(assigned_df)
#      39 # Concatenate all the combined dataframes into one final dataframe
# ---> 40 final_df = pd.concat(combined_dfs, ignore_index=True)
#      42 # Optionally, assign the final concatenated dataframe to a dynamic variable
#      43 globals()['df_assign_all'] = final_df
#
# File c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
assign_new =  assign_old_assign_new.loc[ ~(assign_old_assign_new['status_lm'] == 'SAVE')]

# %%
assign_new
# Out:
#        base_date  customer_no    customer_no  principal_balance  \
# 0     02-04-2568  12210000423  1239900088804             372444
# 1     02-04-2568  12180042213  3249900073161             332923
# 2     02-04-2568  14231031718  1219900085104             299988
# 3     02-04-2568  12210001759  3400800362960             271076
# 4     02-04-2568  12180039099  3110300008086             259469
# ...          ...          ...            ...                ...
# 1581  02-04-2568  14230258379  1250101471889               1003
# 1582  02-04-2568  14230264070  1310700304873                876
# 1583  02-04-2568  12180054313  5450600051614                726
# 1584  02-04-2568  14230936321  1470900121844                258
# 1585  02-04-2568  14230965518  3320100407252                170
#
#       total_unclaimed_amt  repayment_target_amount  overdue_days(morning)  \
# 0                       0                    18062                     32
# 1                       0                    15743                     32
# 2                       0                    11467                     32
# 3                       0                    13248                     32
# 4                       0                    12241                     32
# ...                   ...                      ...                    ...
# 1581                    0                     1025                     32
# 1582                    0                      918                     32
# 1583                    0                      320                     32
# 1584                    0                      262                     32
# 1585                    0                      170                     32
#
#       overdue_cnt(morning)  overdue_days  num_of_overdue_months  ... ever  \
# 0                        2            32                      2  ...    N
# 1                        2            32                      2  ...    N
# 2                        2            32                      2  ...    N
# 3                        2            32                      2  ...    N
# 4                        2            32                      2  ...    Y
# ...                    ...           ...                    ...  ...  ...
# 1581                     2            32                      2  ...    N
# 1582                     2            32                      2  ...    N
# 1583                     2            32                      2  ...    Y
# 1584                     2            32                      2  ...    N
# 1585                     2            32                      2  ...    N
#
#      product_df1 status_lm    old_oa new_oa  product_val  product_df2  \
# 0       RL ML TL    UNSAVE  In-House    NaN     RL ML TL     RL ML TL
# 1       RL ML TL    UNSAVE       DHA    NaN     RL ML TL     RL ML TL
# 2       RL ML TL    UNSAVE       PCN    NaN     RL ML TL     RL ML TL
# 3       RL ML TL    UNSAVE       MMN    NaN     RL ML TL     RL ML TL
# 4       RL ML TL    UNSAVE       DHA    NaN     RL ML TL     RL ML TL
# ...          ...       ...       ...    ...          ...          ...
# 1581    RL ML TL    UNSAVE       PCN    NaN     RL ML TL     RL ML TL
# 1582    RL ML TL    UNSAVE       ACT    NaN     RL ML TL     RL ML TL
# 1583    RL ML TL    UNSAVE       KWC    NaN     RL ML TL     RL ML TL
# 1584    RL ML TL    UNSAVE       KWC    NaN     RL ML TL     RL ML TL
# 1585    RL ML TL    UNSAVE       PCN    NaN     RL ML TL     RL ML TL
#
#             bucket  group            assign_type
# 0     XDAY-OD1-OD2      7  assign_old_assign_new
# 1     XDAY-OD1-OD2      7  assign_old_assign_new
# 2     XDAY-OD1-OD2      7  assign_old_assign_new
# 3     XDAY-OD1-OD2      7  assign_old_assign_new
# 4     XDAY-OD1-OD2      7  assign_old_assign_new
# ...            ...    ...                    ...
# 1581  XDAY-OD1-OD2      7  assign_old_assign_new
# 1582  XDAY-OD1-OD2      7  assign_old_assign_new
# 1583  XDAY-OD1-OD2      7  assign_old_assign_new
# 1584  XDAY-OD1-OD2      7  assign_old_assign_new
# 1585  XDAY-OD1-OD2      7  assign_old_assign_new
#
# [1586 rows x 89 columns]

# %%
oa_proportion
# Out:
#      product                            bucket %assign        oa  group  \
# 0        H4C                              XDAY    1.00  In-House      1
# 1        H4C                           OD1-OD2    1.00       JMT      2
# 2        C4C  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL    0.60       DHA      3
# 3        C4C  XDAY-OD1-OD2-OD3-OD4-OD5-OD6-NPL    0.40       PCN      3
# 4        SF+                             X-DAY    1.00  In-House      4
# 5        SF+                           OD1-OD2    1.00  In-House      5
# 6        SF+                               NPL    0.20      THAS      6
# 7        SF+                               NPL    0.18       LBR      6
# 8        SF+                               NPL    0.17       ASJ      6
# 9        SF+                               NPL    0.16       WSP      6
# 10       SF+                               NPL    0.15       PCN      6
# 11       SF+                               NPL    0.14       MGC      6
# 12  RL ML TL                      XDAY-OD1-OD2    0.20       PCN      7
# 13  RL ML TL                      XDAY-OD1-OD2    0.19       ACT      7
# 14  RL ML TL                      XDAY-OD1-OD2    0.14  In-House      7
# 15  RL ML TL                      XDAY-OD1-OD2    0.17       DHA      7
# 16  RL ML TL                      XDAY-OD1-OD2    0.12       KOR      7
# 17  RL ML TL                      XDAY-OD1-OD2    0.08       KWC      7
# 18  RL ML TL                      XDAY-OD1-OD2    0.10       MMN      7
# 19  RL ML TL                   OD3-OD4-OD5-OD6    0.32       KWC      8
# 20  RL ML TL                   OD3-OD4-OD5-OD6    0.27       MMN      8
# 21  RL ML TL                   OD3-OD4-OD5-OD6    0.23       GMV      8
# 22  RL ML TL                   OD3-OD4-OD5-OD6    0.18       UPC      8
#
#               assign_type
# 0              assign_all
# 1              assign_all
# 2     save_old_assign_new
# 3     save_old_assign_new
# 4              assign_all
# 5              assign_all
# 6     save_old_assign_new
# 7     save_old_assign_new
# 8     save_old_assign_new
# 9     save_old_assign_new
# 10    save_old_assign_new
# 11    save_old_assign_new
# 12  assign_old_assign_new
# 13  assign_old_assign_new
# 14  assign_old_assign_new
# 15  assign_old_assign_new
# 16  assign_old_assign_new
# 17  assign_old_assign_new
# 18  assign_old_assign_new
# 19    save_old_assign_new
# 20    save_old_assign_new
# 21    save_old_assign_new
# 22    save_old_assign_new

# %%
assign_new= assign_to_oa(assign_new)

# %%
assign_new['contract_no'] = assign_new['contract_no'].astype(str)

# %%
assign_new.to_excel('./output/od1_rlmltl.xlsx')

# %%
assign_old_assign_new = pd.concat([assign_old.reset_index(drop=True), 
           assign_new.reset_index(drop=True)],  ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 3
#       1 assign_old_assign_new = ar_merge[ar_merge['assign_type'] == 'assign_old_assign_new'].reset_index(drop=True)
#       2 assign_old  = assign_old_assign_new.loc[ (assign_old_assign_new['status_lm'] == 'SAVE')]
# ----> 3 assign_old= assign_to_oa(assign_old)
#       4 assign_new =  assign_old_assign_new.loc[ ~(assign_old_assign_new['status_lm'] == 'SAVE')]
#       5 assign_new= assign_to_oa(assign_new)
#
# Cell In[81], line 40, in assign_to_oa(df_toassign)
#      37     combined_dfs.append(assigned_df)
#      39 # Concatenate all the combined dataframes into one final dataframe
# ---> 40 final_df = pd.concat(combined_dfs, ignore_index=True)
#      42 # Optionally, assign the final concatenated dataframe to a dynamic variable
#      43 globals()['df_assign_all'] = final_df
#
# File c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File c:\Users\Sireetron\automated\kbj_automation\.venv\Lib\site-packages\pandas\core\reshape\concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
final = pd.concat([save_old_assign_new.reset_index(drop=True), 
           assign_all.reset_index(drop=True), 
           assign_old_assign_new.reset_index(drop=True)], ignore_index=True)

# %%
final.to_csv('./output/assignbycondition.csv')

# %%
ar_path = glob.glob("./input/AR/*")[0].split('\\')[-1]  
ar = read_file('./input/AR/',ar_path)
ar_path_name = re.sub(r'\.(csv|xlsx)$', '', ar_path)

# %%
ar_path_name
# Out:
# 'Ex. data assign'
