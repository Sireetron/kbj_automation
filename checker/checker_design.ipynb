# %%
import pandas as pd
# from utils import all_history, transform_files
import glob
import numpy as np
import pandas as pd
import glob
# import win32com.client as win32
import jaydebeapi
# from const import QUERY, CONNECT
import re

# %%
import glob
""
# Out:
# ''

# %%
glob.glob("./input/assign_input/*")
# Out:
# ['./input/assign_input\\SMS.xlsx']

# %%
re.sub(r'\.(csv|xlsx)$', '', glob.glob("./input/assign_input/*")[0].split('\\')[1])
# Out:
# 'SMS'

# %%
assign = pd.read_excel(f"./input/1stday/3.Total assign Mar'25 (1).xlsx", dtype={'Mobile No.': str, 
                                                        })

# %%
assign.columns
# Out:
# Index(['Base date', 'Customer No', 'Customer ID No', 'Principal balance',
#        'Total Unclaimed Amt.', 'Repayment Target Amount',
#        'Overdue days(Morning)', 'Overdue Cnt(Morning)', 'Overdue days',
#        'Num of Overdue months', 'Overdue Months Division Code', 'Corp. Info.',
#        'Sales product code', 'Loan No.', 'Customer Name', 'Customer ID No.',
#        'Mobile No.', 'Address(Home)', 'Post code', 'Phone No.(Home)',
#        'Address(Office)', 'Post code.1', 'Biz phone No.',
#        'Address (place of residence)', 'Post Code', 'Phone No.',
#        'Delivery Address', 'Post code.2', 'Delivery phone No.',
#        'Customer relationship', 'Related person', 'Phone No. 1',
#        'Customer relationship.1', 'Related person.1', 'Phone No. 2',
#        'Branch code', 'Outstanding Balance', 'Loan date', 'Installment Count',
#        'Product Name', 'Last Money Received date', 'Last payment Amt.',
#        'Loan Amt.', 'Principal', 'Monthly payment Amt.',
#        ' First_Settlement_date', 'Last payment date', 'Billing interest Amt.',
#        'Billing Credit Usage Amount', 'Overdue start date', 'Overdue Int.',
#        'Overdue Credit Usage Amount', 'Collection Fee', 'Overdue Sum. Amt.',
#        'Overdue Months Division Code.1', 'DOB', 'Marital status',
#        'Phone No. 3', 'Company name', 'Company Extension No.',
#        'Headquarter Phone No', 'Headquarter Extension No.', 'Monthly income',
#        'Email Address', 'Next payment due date', 'Next Payment Amt',
#        'Payment date', 'Total count', 'Number of deposit on 1st of month',
#        'Number of deposit on/Before 5th of month',
#        'Number of deposit before 24th of month',
#        'Number of deposit before 25th of month',
#        'Number of deposit at the end of month.', 'Last payment Amt..1',
#        'Biz. industry code', 'Occupation', 'Sales product code.1',
#        'Waived Processing Amt.(Xday)', 'Extend term changed count', 'Ever',
#        'Product', 'Status LM', 'Old OA', 'New OA', 'Reason', 'Collector'],
#       dtype='object')

# %%
assign_delay = assign.loc[
    (assign['New OA'] == 'Delay calling')
][['Base date','Customer ID No','Principal balance','Customer Name', 'Sales product code','Mobile No.'
        ,'Overdue Months Division Code','Loan No.','Overdue days(Morning)','Status LM','New OA' ]]

# %%
assign_delay
# Out:
#         Base date  Customer ID No  Principal balance           Customer Name  \
# 1      02-03-2568   3100700619422           82466.01       วัชรพล ชัยสวัสดิ์
# 2      02-03-2568   3101300732206             424.47       ธนะโชติ ตันทิวากร
# 4      02-03-2568   3100503160974           10233.80        ชัยวัฒน์ สวนแก้ว
# 5      02-03-2568   1459900793051            2590.98      จันทรกานต์ ปรินแคน
# 7      02-03-2568   3101701963284           18242.39           สุทิน หวังบู่
# ...           ...             ...                ...                     ...
# 38104  02-03-2568   3489900074743          263412.48  ณัฐนันท์ สิทธิธรรมพงศ์
# 38105  02-03-2568   3610500062721           62662.70          อนงค์ ขุมเพ็ชร
# 38109  02-03-2568   3800900578278           20232.96          ภิรมย์ จริตงาม
# 38110  02-03-2568   3820800162096           46587.05         นิตยา ชาติมณตรี
# 38112  02-03-2568   1100400134435           58220.40        วลีวรรณ เรืองราย
#
#       Sales product code  Mobile No. Overdue Months Division Code  \
# 1                A301:RL  0859110632                  Grace_X-Day
# 2                A401:ML  0870876086                  Grace_X-Day
# 4                A401:ML  0837760058                  Grace_X-Day
# 5                A401:ML  0983074011                  Grace_X-Day
# 7                A301:RL  0843095398                  Grace_X-Day
# ...                  ...         ...                          ...
# 38104            A301:RL  0865649741                  Grace_X-Day
# 38105            A301:RL  0817357962                  Grace_X-Day
# 38109            A301:RL  0902252226                  Grace_X-Day
# 38110            A301:RL  0878841915                  Grace_X-Day
# 38112            A301:RL  0808692914                  Grace_X-Day
#
#                Loan No.  Overdue days(Morning) Status LM         New OA
# 1      7221030100003286                      1       NEW  Delay calling
# 2      7230340100241933                      1      SAVE  Delay calling
# 4      7230940101310936                      1       NEW  Delay calling
# 5      7230440100394365                      1       NEW  Delay calling
# 7      7230830101060374                      1      SAVE  Delay calling
# ...                 ...                    ...       ...            ...
# 38104  5000361031096790                      1       NEW  Delay calling
# 38105  5000559101019301                      1      SAVE  Delay calling
# 38109  5000460081037663                      1      SAVE  Delay calling
# 38110  5000159091005943                      1      SAVE  Delay calling
# 38112  5000160051031619                      1       NEW  Delay calling
#
# [15182 rows x 11 columns]

# %%
assign_delay['Customer Name'] = assign_delay['Customer Name'].str.strip()

# %%
assign_delay[['NAME', 'SURNAME']] = assign_delay['Customer Name'].str.split(n=1, expand=True)

# %%
assign_delay
# Out:
#         Base date  Customer ID No  Principal balance           Customer Name  \
# 1      02-03-2568   3100700619422           82466.01       วัชรพล ชัยสวัสดิ์
# 2      02-03-2568   3101300732206             424.47       ธนะโชติ ตันทิวากร
# 4      02-03-2568   3100503160974           10233.80        ชัยวัฒน์ สวนแก้ว
# 5      02-03-2568   1459900793051            2590.98      จันทรกานต์ ปรินแคน
# 7      02-03-2568   3101701963284           18242.39           สุทิน หวังบู่
# ...           ...             ...                ...                     ...
# 38104  02-03-2568   3489900074743          263412.48  ณัฐนันท์ สิทธิธรรมพงศ์
# 38105  02-03-2568   3610500062721           62662.70          อนงค์ ขุมเพ็ชร
# 38109  02-03-2568   3800900578278           20232.96          ภิรมย์ จริตงาม
# 38110  02-03-2568   3820800162096           46587.05         นิตยา ชาติมณตรี
# 38112  02-03-2568   1100400134435           58220.40        วลีวรรณ เรืองราย
#
#       Sales product code  Mobile No. Overdue Months Division Code  \
# 1                A301:RL  0859110632                  Grace_X-Day
# 2                A401:ML  0870876086                  Grace_X-Day
# 4                A401:ML  0837760058                  Grace_X-Day
# 5                A401:ML  0983074011                  Grace_X-Day
# 7                A301:RL  0843095398                  Grace_X-Day
# ...                  ...         ...                          ...
# 38104            A301:RL  0865649741                  Grace_X-Day
# 38105            A301:RL  0817357962                  Grace_X-Day
# 38109            A301:RL  0902252226                  Grace_X-Day
# 38110            A301:RL  0878841915                  Grace_X-Day
# 38112            A301:RL  0808692914                  Grace_X-Day
#
#                Loan No.  Overdue days(Morning) Status LM         New OA  \
# 1      7221030100003286                      1       NEW  Delay calling
# 2      7230340100241933                      1      SAVE  Delay calling
# 4      7230940101310936                      1       NEW  Delay calling
# 5      7230440100394365                      1       NEW  Delay calling
# 7      7230830101060374                      1      SAVE  Delay calling
# ...                 ...                    ...       ...            ...
# 38104  5000361031096790                      1       NEW  Delay calling
# 38105  5000559101019301                      1      SAVE  Delay calling
# 38109  5000460081037663                      1      SAVE  Delay calling
# 38110  5000159091005943                      1      SAVE  Delay calling
# 38112  5000160051031619                      1       NEW  Delay calling
#
#              NAME        SURNAME
# 1          วัชรพล     ชัยสวัสดิ์
# 2         ธนะโชติ      ตันทิวากร
# 4        ชัยวัฒน์        สวนแก้ว
# 5      จันทรกานต์        ปรินแคน
# 7           สุทิน        หวังบู่
# ...           ...            ...
# 38104    ณัฐนันท์  สิทธิธรรมพงศ์
# 38105       อนงค์       ขุมเพ็ชร
# 38109      ภิรมย์        จริตงาม
# 38110       นิตยา      ชาติมณตรี
# 38112     วลีวรรณ       เรืองราย
#
# [15182 rows x 13 columns]

# %%
customer = pd.read_csv('./input/1stday/customerdata.csv', dtype={'MOBILE_PHONE_NO_VAL': str, 
                                                           'NATIONAL_ID_VAL': str, 
                                                           'CONTRACT_NO_VAL': str})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 customer = pd.read_csv('./input/1stday/customerdata.csv', dtype={'MOBILE_PHONE_NO_VAL': str,
#       2                                                            'NATIONAL_ID_VAL': str,
#       3                                                            'CONTRACT_NO_VAL': str})
#
# NameError: name 'pd' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
assign_delay['Customer ID No'] = assign_delay['Customer ID No'].astype(str)
assign_delay['Loan No.'] = assign_delay['Loan No.'].astype(str)
customer['CONTRACT_NO_VAL'] = customer['CONTRACT_NO_VAL'].astype(str)
customer['NATIONAL_ID'] = customer['NATIONAL_ID'].astype(str)

# %%
assign_delay.columns
# Out:
# Index(['Base date', 'Customer ID No', 'Principal balance', 'Customer Name',
#        'Sales product code', 'Mobile No.', 'Overdue Months Division Code',
#        'Loan No.', 'Overdue days(Morning)', 'Status LM', 'New OA', 'NAME',
#        'SURNAME'],
#       dtype='object')

# %%
# assign_delay.merge(customer,left_no ='Customer ID No',right_no='NATIONAL_ID')
assign_delay_merge = assign_delay.merge(customer, left_on=['Customer ID No', 'Loan No.'], right_on=['NATIONAL_ID' ,'CONTRACT_NO_VAL'], how='left')

# %%
assign_delay_merge.columns
# Out:
# Index(['Base date', 'Customer ID No', 'Principal balance', 'Customer Name',
#        'Sales product code', 'Mobile No.', 'Overdue Months Division Code',
#        'Loan No.', 'Overdue days(Morning)', 'Status LM', 'New OA', 'NAME',
#        'SURNAME', 'AS_OF_DATE', 'CONTRACT_NO_VAL', 'NATIONAL_ID', 'CHANNEL',
#        'MONTHLY_INST_AMT', 'FIRST_DUE_DATE', 'NAME_VAL', 'SURNAME_VAL',
#        'MOBILE_PHONE_NO_VAL', 'RESIDENT_ADDRESS'],
#       dtype='object')

# %%
assign_delay_merge
# Out:
#         Base date Customer ID No  Principal balance           Customer Name  \
# 0      02-03-2568  3100700619422           82466.01       วัชรพล ชัยสวัสดิ์
# 1      02-03-2568  3101300732206             424.47       ธนะโชติ ตันทิวากร
# 2      02-03-2568  3100503160974           10233.80        ชัยวัฒน์ สวนแก้ว
# 3      02-03-2568  1459900793051            2590.98      จันทรกานต์ ปรินแคน
# 4      02-03-2568  3101701963284           18242.39           สุทิน หวังบู่
# ...           ...            ...                ...                     ...
# 15177  02-03-2568  3489900074743          263412.48  ณัฐนันท์ สิทธิธรรมพงศ์
# 15178  02-03-2568  3610500062721           62662.70          อนงค์ ขุมเพ็ชร
# 15179  02-03-2568  3800900578278           20232.96          ภิรมย์ จริตงาม
# 15180  02-03-2568  3820800162096           46587.05         นิตยา ชาติมณตรี
# 15181  02-03-2568  1100400134435           58220.40        วลีวรรณ เรืองราย
#
#       Sales product code  Mobile No. Overdue Months Division Code  \
# 0                A301:RL  0859110632                  Grace_X-Day
# 1                A401:ML  0870876086                  Grace_X-Day
# 2                A401:ML  0837760058                  Grace_X-Day
# 3                A401:ML  0983074011                  Grace_X-Day
# 4                A301:RL  0843095398                  Grace_X-Day
# ...                  ...         ...                          ...
# 15177            A301:RL  0865649741                  Grace_X-Day
# 15178            A301:RL  0817357962                  Grace_X-Day
# 15179            A301:RL  0902252226                  Grace_X-Day
# 15180            A301:RL  0878841915                  Grace_X-Day
# 15181            A301:RL  0808692914                  Grace_X-Day
#
#                Loan No.  Overdue days(Morning) Status LM  ...  \
# 0      7221030100003286                      1       NEW  ...
# 1      7230340100241933                      1      SAVE  ...
# 2      7230940101310936                      1       NEW  ...
# 3      7230440100394365                      1       NEW  ...
# 4      7230830101060374                      1      SAVE  ...
# ...                 ...                    ...       ...  ...
# 15177  5000361031096790                      1       NEW  ...
# 15178  5000559101019301                      1      SAVE  ...
# 15179  5000460081037663                      1      SAVE  ...
# 15180  5000159091005943                      1      SAVE  ...
# 15181  5000160051031619                      1       NEW  ...
#
#                     AS_OF_DATE   CONTRACT_NO_VAL    NATIONAL_ID CHANNEL  \
# 0      2025-03-09 00:00:00.000  7221030100003286  3100700619422     NaN
# 1      2025-03-09 00:00:00.000  7230340100241933  3101300732206     NaN
# 2      2025-03-09 00:00:00.000  7230940101310936  3100503160974     NaN
# 3      2025-03-09 00:00:00.000  7230440100394365  1459900793051     NaN
# 4      2025-03-09 00:00:00.000  7230830101060374  3101701963284     NaN
# ...                        ...               ...            ...     ...
# 15177  2025-03-09 00:00:00.000  5000361031096790  3489900074743     NaN
# 15178  2025-03-09 00:00:00.000  5000559101019301  3610500062721     NaN
# 15179  2025-03-09 00:00:00.000  5000460081037663  3800900578278     NaN
# 15180  2025-03-09 00:00:00.000  5000159091005943  3820800162096     NaN
# 15181  2025-03-09 00:00:00.000  5000160051031619  1100400134435     NaN
#
#       MONTHLY_INST_AMT           FIRST_DUE_DATE    NAME_VAL    SURNAME_VAL  \
# 0                 0.00  2022-12-01 00:00:00.000      วัชรพล     ชัยสวัสดิ์
# 1              1318.00  2023-04-01 00:00:00.000     ธนะโชติ      ตันทิวากร
# 2              1405.00  2023-11-01 00:00:00.000    ชัยวัฒน์        สวนแก้ว
# 3               827.00  2023-06-01 00:00:00.000  จันทรกานต์        ปรินแคน
# 4                 0.00  2023-10-01 00:00:00.000       สุทิน        หวังบู่
# ...                ...                      ...         ...            ...
# 15177          8513.89  2018-05-01 00:00:00.000    ณัฐนันท์  สิทธิธรรมพงศ์
# 15178           163.14  2016-11-01 00:00:00.000       อนงค์       ขุมเพ็ชร
# 15179           632.24  2017-10-01 00:00:00.000      ภิรมย์        จริตงาม
# 15180          1140.52  2016-10-01 00:00:00.000       นิตยา      ชาติมณตรี
# 15181             0.00  2017-08-01 00:00:00.000     วลีวรรณ       เรืองราย
#
#       MOBILE_PHONE_NO_VAL                                   RESIDENT_ADDRESS
# 0              0859110632  มบ.Centro บางใหญ่ เลขที่99/15 ถนนซอยวัดลาดปลาด...
# 1              0870876086  1028/16  ซอยตรอกวานิช 2   แขวง ตลาดน้อย เขต สั...
# 2              0837760058    610/150   แขวง คลองถนน เขต สายไหม กรุงเทพมหานคร
# 3              0983074011  1156/635 ถนนสามเสน   แขวง ถนนนครไชยศรี เขต ดุส...
# 4              0843095398  709 ซอยชานเมือง ถนน-   แขวง ดินแดง เขต ดินแดง ...
# ...                   ...                                                ...
# 15177          0865649741  วิทยาลัยเทคโนโลยีอินเตอรืพัฒนศาสตร์ เลขที่ 29/...
# 15178          0817357962  เลขที่ 4 หมู่ที่ 1   ต. ดงขวาง อ. หนองขาหย่าง ...
# 15179          0902252226  เลขที่ 37 หมู่ที่ 5   ต. ถ้ำใหญ่ อ. ทุ่งสง จ. ...
# 15180          0878841915  เลขที่ 74/82-83 ถนนพูนผล   ต. ตลาดเหนือ อ. เมื...
# 15181          0808692914  9ซอยพรามที่2 ซอย 69   แขวง แสมดำ เขต บางขุนเที...
#
# [15182 rows x 23 columns]

# %%
assign_delay_merge['NAME_CHECK'] = assign_delay_merge.apply(
    lambda row: True if row['NAME'] == row['NAME_VAL'] else row['NAME_VAL'],
    axis=1
)

# %%
assign_delay_merge['SURNAME_CHECK'] = assign_delay_merge.apply(
    lambda row: True if row['SURNAME'] == row['SURNAME_VAL'] else row['SURNAME_VAL'],
    axis=1
)

# %%
assign_delay_merge['MOBILE_CHECK'] = assign_delay_merge.apply(
    lambda row: True if row['Mobile No.'] == row['MOBILE_PHONE_NO_VAL'] else row['MOBILE_PHONE_NO_VAL'],
    axis=1
)

# %%
assign_delay_merge
# Out:
#         Base date Customer ID No  Principal balance           Customer Name  \
# 0      02-03-2568  3100700619422           82466.01       วัชรพล ชัยสวัสดิ์
# 1      02-03-2568  3101300732206             424.47       ธนะโชติ ตันทิวากร
# 2      02-03-2568  3100503160974           10233.80        ชัยวัฒน์ สวนแก้ว
# 3      02-03-2568  1459900793051            2590.98      จันทรกานต์ ปรินแคน
# 4      02-03-2568  3101701963284           18242.39           สุทิน หวังบู่
# ...           ...            ...                ...                     ...
# 15177  02-03-2568  3489900074743          263412.48  ณัฐนันท์ สิทธิธรรมพงศ์
# 15178  02-03-2568  3610500062721           62662.70          อนงค์ ขุมเพ็ชร
# 15179  02-03-2568  3800900578278           20232.96          ภิรมย์ จริตงาม
# 15180  02-03-2568  3820800162096           46587.05         นิตยา ชาติมณตรี
# 15181  02-03-2568  1100400134435           58220.40        วลีวรรณ เรืองราย
#
#       Sales product code  Mobile No. Overdue Months Division Code  \
# 0                A301:RL  0859110632                  Grace_X-Day
# 1                A401:ML  0870876086                  Grace_X-Day
# 2                A401:ML  0837760058                  Grace_X-Day
# 3                A401:ML  0983074011                  Grace_X-Day
# 4                A301:RL  0843095398                  Grace_X-Day
# ...                  ...         ...                          ...
# 15177            A301:RL  0865649741                  Grace_X-Day
# 15178            A301:RL  0817357962                  Grace_X-Day
# 15179            A301:RL  0902252226                  Grace_X-Day
# 15180            A301:RL  0878841915                  Grace_X-Day
# 15181            A301:RL  0808692914                  Grace_X-Day
#
#                Loan No.  Overdue days(Morning) Status LM  ...    NATIONAL_ID  \
# 0      7221030100003286                      1       NEW  ...  3100700619422
# 1      7230340100241933                      1      SAVE  ...  3101300732206
# 2      7230940101310936                      1       NEW  ...  3100503160974
# 3      7230440100394365                      1       NEW  ...  1459900793051
# 4      7230830101060374                      1      SAVE  ...  3101701963284
# ...                 ...                    ...       ...  ...            ...
# 15177  5000361031096790                      1       NEW  ...  3489900074743
# 15178  5000559101019301                      1      SAVE  ...  3610500062721
# 15179  5000460081037663                      1      SAVE  ...  3800900578278
# 15180  5000159091005943                      1      SAVE  ...  3820800162096
# 15181  5000160051031619                      1       NEW  ...  1100400134435
#
#       CHANNEL MONTHLY_INST_AMT           FIRST_DUE_DATE    NAME_VAL  \
# 0         NaN             0.00  2022-12-01 00:00:00.000      วัชรพล
# 1         NaN          1318.00  2023-04-01 00:00:00.000     ธนะโชติ
# 2         NaN          1405.00  2023-11-01 00:00:00.000    ชัยวัฒน์
# 3         NaN           827.00  2023-06-01 00:00:00.000  จันทรกานต์
# 4         NaN             0.00  2023-10-01 00:00:00.000       สุทิน
# ...       ...              ...                      ...         ...
# 15177     NaN          8513.89  2018-05-01 00:00:00.000    ณัฐนันท์
# 15178     NaN           163.14  2016-11-01 00:00:00.000       อนงค์
# 15179     NaN           632.24  2017-10-01 00:00:00.000      ภิรมย์
# 15180     NaN          1140.52  2016-10-01 00:00:00.000       นิตยา
# 15181     NaN             0.00  2017-08-01 00:00:00.000     วลีวรรณ
#
#          SURNAME_VAL  MOBILE_PHONE_NO_VAL  \
# 0         ชัยสวัสดิ์           0859110632
# 1          ตันทิวากร           0870876086
# 2            สวนแก้ว           0837760058
# 3            ปรินแคน           0983074011
# 4            หวังบู่           0843095398
# ...              ...                  ...
# 15177  สิทธิธรรมพงศ์           0865649741
# 15178       ขุมเพ็ชร           0817357962
# 15179        จริตงาม           0902252226
# 15180      ชาติมณตรี           0878841915
# 15181       เรืองราย           0808692914
#
#                                         RESIDENT_ADDRESS NAME_CHECK  \
# 0      มบ.Centro บางใหญ่ เลขที่99/15 ถนนซอยวัดลาดปลาด...       True
# 1      1028/16  ซอยตรอกวานิช 2   แขวง ตลาดน้อย เขต สั...       True
# 2        610/150   แขวง คลองถนน เขต สายไหม กรุงเทพมหานคร       True
# 3      1156/635 ถนนสามเสน   แขวง ถนนนครไชยศรี เขต ดุส...       True
# 4      709 ซอยชานเมือง ถนน-   แขวง ดินแดง เขต ดินแดง ...       True
# ...                                                  ...        ...
# 15177  วิทยาลัยเทคโนโลยีอินเตอรืพัฒนศาสตร์ เลขที่ 29/...       True
# 15178  เลขที่ 4 หมู่ที่ 1   ต. ดงขวาง อ. หนองขาหย่าง ...       True
# 15179  เลขที่ 37 หมู่ที่ 5   ต. ถ้ำใหญ่ อ. ทุ่งสง จ. ...       True
# 15180  เลขที่ 74/82-83 ถนนพูนผล   ต. ตลาดเหนือ อ. เมื...       True
# 15181  9ซอยพรามที่2 ซอย 69   แขวง แสมดำ เขต บางขุนเที...       True
#
#       SURNAME_CHECK
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 15177          True
# 15178          True
# 15179          True
# 15180          True
# 15181          True
#
# [15182 rows x 25 columns]

# %%
assign_delay_merge['LAST4DIGIT'] = assign_delay_merge['Loan No.'].str[-4:]

# %%
assign_delay_merge = assign_delay_merge[['Base date', 'Customer ID No', 'Principal balance', 'Customer Name',
       'Sales product code', 'Mobile No.', 'Overdue Months Division Code',
       'Loan No.', 'Overdue days(Morning)', 'Status LM', 'New OA', 'NAME',
       'SURNAME', 'AS_OF_DATE', 'CHANNEL',
       'MONTHLY_INST_AMT', 'FIRST_DUE_DATE','RESIDENT_ADDRESS', 'NAME_CHECK',
       'SURNAME_CHECK', 'MOBILE_CHECK','LAST4DIGIT']]

# %%
assign_delay_merge
# Out:
#         Base date Customer ID No  Principal balance           Customer Name  \
# 0      02-03-2568  3100700619422           82466.01       วัชรพล ชัยสวัสดิ์
# 1      02-03-2568  3101300732206             424.47       ธนะโชติ ตันทิวากร
# 2      02-03-2568  3100503160974           10233.80        ชัยวัฒน์ สวนแก้ว
# 3      02-03-2568  1459900793051            2590.98      จันทรกานต์ ปรินแคน
# 4      02-03-2568  3101701963284           18242.39           สุทิน หวังบู่
# ...           ...            ...                ...                     ...
# 15177  02-03-2568  3489900074743          263412.48  ณัฐนันท์ สิทธิธรรมพงศ์
# 15178  02-03-2568  3610500062721           62662.70          อนงค์ ขุมเพ็ชร
# 15179  02-03-2568  3800900578278           20232.96          ภิรมย์ จริตงาม
# 15180  02-03-2568  3820800162096           46587.05         นิตยา ชาติมณตรี
# 15181  02-03-2568  1100400134435           58220.40        วลีวรรณ เรืองราย
#
#       Sales product code  Mobile No. Overdue Months Division Code  \
# 0                A301:RL  0859110632                  Grace_X-Day
# 1                A401:ML  0870876086                  Grace_X-Day
# 2                A401:ML  0837760058                  Grace_X-Day
# 3                A401:ML  0983074011                  Grace_X-Day
# 4                A301:RL  0843095398                  Grace_X-Day
# ...                  ...         ...                          ...
# 15177            A301:RL  0865649741                  Grace_X-Day
# 15178            A301:RL  0817357962                  Grace_X-Day
# 15179            A301:RL  0902252226                  Grace_X-Day
# 15180            A301:RL  0878841915                  Grace_X-Day
# 15181            A301:RL  0808692914                  Grace_X-Day
#
#                Loan No.  Overdue days(Morning) Status LM  ...        SURNAME  \
# 0      7221030100003286                      1       NEW  ...     ชัยสวัสดิ์
# 1      7230340100241933                      1      SAVE  ...      ตันทิวากร
# 2      7230940101310936                      1       NEW  ...        สวนแก้ว
# 3      7230440100394365                      1       NEW  ...        ปรินแคน
# 4      7230830101060374                      1      SAVE  ...        หวังบู่
# ...                 ...                    ...       ...  ...            ...
# 15177  5000361031096790                      1       NEW  ...  สิทธิธรรมพงศ์
# 15178  5000559101019301                      1      SAVE  ...       ขุมเพ็ชร
# 15179  5000460081037663                      1      SAVE  ...        จริตงาม
# 15180  5000159091005943                      1      SAVE  ...      ชาติมณตรี
# 15181  5000160051031619                      1       NEW  ...       เรืองราย
#
#                     AS_OF_DATE CHANNEL MONTHLY_INST_AMT  \
# 0      2025-03-09 00:00:00.000     NaN             0.00
# 1      2025-03-09 00:00:00.000     NaN          1318.00
# 2      2025-03-09 00:00:00.000     NaN          1405.00
# 3      2025-03-09 00:00:00.000     NaN           827.00
# 4      2025-03-09 00:00:00.000     NaN             0.00
# ...                        ...     ...              ...
# 15177  2025-03-09 00:00:00.000     NaN          8513.89
# 15178  2025-03-09 00:00:00.000     NaN           163.14
# 15179  2025-03-09 00:00:00.000     NaN           632.24
# 15180  2025-03-09 00:00:00.000     NaN          1140.52
# 15181  2025-03-09 00:00:00.000     NaN             0.00
#
#                 FIRST_DUE_DATE  \
# 0      2022-12-01 00:00:00.000
# 1      2023-04-01 00:00:00.000
# 2      2023-11-01 00:00:00.000
# 3      2023-06-01 00:00:00.000
# 4      2023-10-01 00:00:00.000
# ...                        ...
# 15177  2018-05-01 00:00:00.000
# 15178  2016-11-01 00:00:00.000
# 15179  2017-10-01 00:00:00.000
# 15180  2016-10-01 00:00:00.000
# 15181  2017-08-01 00:00:00.000
#
#                                         RESIDENT_ADDRESS NAME_CHECK  \
# 0      มบ.Centro บางใหญ่ เลขที่99/15 ถนนซอยวัดลาดปลาด...       True
# 1      1028/16  ซอยตรอกวานิช 2   แขวง ตลาดน้อย เขต สั...       True
# 2        610/150   แขวง คลองถนน เขต สายไหม กรุงเทพมหานคร       True
# 3      1156/635 ถนนสามเสน   แขวง ถนนนครไชยศรี เขต ดุส...       True
# 4      709 ซอยชานเมือง ถนน-   แขวง ดินแดง เขต ดินแดง ...       True
# ...                                                  ...        ...
# 15177  วิทยาลัยเทคโนโลยีอินเตอรืพัฒนศาสตร์ เลขที่ 29/...       True
# 15178  เลขที่ 4 หมู่ที่ 1   ต. ดงขวาง อ. หนองขาหย่าง ...       True
# 15179  เลขที่ 37 หมู่ที่ 5   ต. ถ้ำใหญ่ อ. ทุ่งสง จ. ...       True
# 15180  เลขที่ 74/82-83 ถนนพูนผล   ต. ตลาดเหนือ อ. เมื...       True
# 15181  9ซอยพรามที่2 ซอย 69   แขวง แสมดำ เขต บางขุนเที...       True
#
#       SURNAME_CHECK MOBILE_CHECK LAST4DIGIT
# 0              True         True       3286
# 1              True         True       1933
# 2              True         True       0936
# 3              True         True       4365
# 4              True         True       0374
# ...             ...          ...        ...
# 15177          True         True       6790
# 15178          True         True       9301
# 15179          True         True       7663
# 15180          True         True       5943
# 15181          True         True       1619
#
# [15182 rows x 22 columns]

# %% [markdown]
# ----

# %%
assign_delay_merge.loc[assign_delay_merge['MOBILE_CHECK'] != True][['Base date', 'Loan No.','Customer ID No', 'Principal balance', 'Customer Name',
       'Sales product code', 'Mobile No.', 'Overdue Months Division Code','Overdue days(Morning)', 'Status LM', 'New OA', 'AS_OF_DATE', 'CHANNEL',
       'MONTHLY_INST_AMT', 'FIRST_DUE_DATE','RESIDENT_ADDRESS', 'NAME_CHECK',
       'SURNAME_CHECK', 'MOBILE_CHECK']].shape[0]
# Out:
# 15

# %%
assign_delay_merge.loc[assign_delay_merge['Overdue Months Division Code'] == '']
# Out:
#         Base date Customer ID No  Principal balance           Customer Name  \
# 0      02-03-2568  3100700619422           82466.01       วัชรพล ชัยสวัสดิ์
# 1      02-03-2568  3101300732206             424.47       ธนะโชติ ตันทิวากร
# 2      02-03-2568  3100503160974           10233.80        ชัยวัฒน์ สวนแก้ว
# 3      02-03-2568  1459900793051            2590.98      จันทรกานต์ ปรินแคน
# 4      02-03-2568  3101701963284           18242.39           สุทิน หวังบู่
# ...           ...            ...                ...                     ...
# 15177  02-03-2568  3489900074743          263412.48  ณัฐนันท์ สิทธิธรรมพงศ์
# 15178  02-03-2568  3610500062721           62662.70          อนงค์ ขุมเพ็ชร
# 15179  02-03-2568  3800900578278           20232.96          ภิรมย์ จริตงาม
# 15180  02-03-2568  3820800162096           46587.05         นิตยา ชาติมณตรี
# 15181  02-03-2568  1100400134435           58220.40        วลีวรรณ เรืองราย
#
#       Sales product code  Mobile No. Overdue Months Division Code  \
# 0                A301:RL  0859110632                  Grace_X-Day
# 1                A401:ML  0870876086                  Grace_X-Day
# 2                A401:ML  0837760058                  Grace_X-Day
# 3                A401:ML  0983074011                  Grace_X-Day
# 4                A301:RL  0843095398                  Grace_X-Day
# ...                  ...         ...                          ...
# 15177            A301:RL  0865649741                  Grace_X-Day
# 15178            A301:RL  0817357962                  Grace_X-Day
# 15179            A301:RL  0902252226                  Grace_X-Day
# 15180            A301:RL  0878841915                  Grace_X-Day
# 15181            A301:RL  0808692914                  Grace_X-Day
#
#                Loan No.  Overdue days(Morning) Status LM  ...        SURNAME  \
# 0      7221030100003286                      1       NEW  ...     ชัยสวัสดิ์
# 1      7230340100241933                      1      SAVE  ...      ตันทิวากร
# 2      7230940101310936                      1       NEW  ...        สวนแก้ว
# 3      7230440100394365                      1       NEW  ...        ปรินแคน
# 4      7230830101060374                      1      SAVE  ...        หวังบู่
# ...                 ...                    ...       ...  ...            ...
# 15177  5000361031096790                      1       NEW  ...  สิทธิธรรมพงศ์
# 15178  5000559101019301                      1      SAVE  ...       ขุมเพ็ชร
# 15179  5000460081037663                      1      SAVE  ...        จริตงาม
# 15180  5000159091005943                      1      SAVE  ...      ชาติมณตรี
# 15181  5000160051031619                      1       NEW  ...       เรืองราย
#
#                     AS_OF_DATE CHANNEL MONTHLY_INST_AMT  \
# 0      2025-03-09 00:00:00.000     NaN             0.00
# 1      2025-03-09 00:00:00.000     NaN          1318.00
# 2      2025-03-09 00:00:00.000     NaN          1405.00
# 3      2025-03-09 00:00:00.000     NaN           827.00
# 4      2025-03-09 00:00:00.000     NaN             0.00
# ...                        ...     ...              ...
# 15177  2025-03-09 00:00:00.000     NaN          8513.89
# 15178  2025-03-09 00:00:00.000     NaN           163.14
# 15179  2025-03-09 00:00:00.000     NaN           632.24
# 15180  2025-03-09 00:00:00.000     NaN          1140.52
# 15181  2025-03-09 00:00:00.000     NaN             0.00
#
#                 FIRST_DUE_DATE  \
# 0      2022-12-01 00:00:00.000
# 1      2023-04-01 00:00:00.000
# 2      2023-11-01 00:00:00.000
# 3      2023-06-01 00:00:00.000
# 4      2023-10-01 00:00:00.000
# ...                        ...
# 15177  2018-05-01 00:00:00.000
# 15178  2016-11-01 00:00:00.000
# 15179  2017-10-01 00:00:00.000
# 15180  2016-10-01 00:00:00.000
# 15181  2017-08-01 00:00:00.000
#
#                                         RESIDENT_ADDRESS NAME_CHECK  \
# 0      มบ.Centro บางใหญ่ เลขที่99/15 ถนนซอยวัดลาดปลาด...       True
# 1      1028/16  ซอยตรอกวานิช 2   แขวง ตลาดน้อย เขต สั...       True
# 2        610/150   แขวง คลองถนน เขต สายไหม กรุงเทพมหานคร       True
# 3      1156/635 ถนนสามเสน   แขวง ถนนนครไชยศรี เขต ดุส...       True
# 4      709 ซอยชานเมือง ถนน-   แขวง ดินแดง เขต ดินแดง ...       True
# ...                                                  ...        ...
# 15177  วิทยาลัยเทคโนโลยีอินเตอรืพัฒนศาสตร์ เลขที่ 29/...       True
# 15178  เลขที่ 4 หมู่ที่ 1   ต. ดงขวาง อ. หนองขาหย่าง ...       True
# 15179  เลขที่ 37 หมู่ที่ 5   ต. ถ้ำใหญ่ อ. ทุ่งสง จ. ...       True
# 15180  เลขที่ 74/82-83 ถนนพูนผล   ต. ตลาดเหนือ อ. เมื...       True
# 15181  9ซอยพรามที่2 ซอย 69   แขวง แสมดำ เขต บางขุนเที...       True
#
#       SURNAME_CHECK MOBILE_CHECK last4digit
# 0              True         True       3286
# 1              True         True       1933
# 2              True         True       0936
# 3              True         True       4365
# 4              True         True       0374
# ...             ...          ...        ...
# 15177          True         True       6790
# 15178          True         True       9301
# 15179          True         True       7663
# 15180          True         True       5943
# 15181          True         True       1619
#
# [15182 rows x 22 columns]

# %%
file = glob.glob("./input/1stday/*assign*.xlsx")[0].split('\\')[1]

# %%
file
# Out:
# "3.Total assign Mar'25 (1).xlsx"
